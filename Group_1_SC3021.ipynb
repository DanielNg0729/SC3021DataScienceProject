# %% [markdown]
# # **Predictive Regression Modelling of HDB Resale Prices in Relation to Urban Accessibility and Macroeconomic Trends**
# ## **SC3021 Project - AY25/26 Semester 2**
# ## **BACF1 Team 1**
# Kwok Weng Jian (U2510454J)
# Chew En Yu (U2510555H)
# Nguyen Hoang Duong (U2510950H)
#
# # **Introduction**
# The public housing market in Singapore serves as a critical pillar of national stability, housing over 80% of the resident population. However, the HDB resale market operates on open market principles, where transaction prices fluctuate significantly based on intrinsic property attributes, locational convenience, and macroeconomic conditions. Understanding the valuation dynamics of resale flats is essential for prospective homeowners, urban planners, and policymakers to navigate housing affordability and asset progression.
#
# # **Project Goal**
# This project aims to engineer a predictive model for HDB resale prices by analyzing the correlation between three primary dimensions:
#
# * Structural Attributes (Age, floor area, lease remainder)
#
# * Locational Utility (Proximity to transport and top-tier education)
# * Macroeconomic Trends (Inflation and purchasing power)
#
# ##**Our Hypothesis**
# * Locational accessibility such as proximity to MRT nodes and primary schools is positively correlated with resale valuation.
#
# * Remaining lease tenure is positively correlated with price.
#
# * Inflationary pressure (CPI) significantly distorts historical pricing, requiring normalization to compare value over time accurately.
#
# <br>
#
# ####To validate these hypotheses and construct a robust pricing model, we have curated a comprehensive data architecture comprising six distinct components. These datasets were selected to ensure our model captures both the physical reality of the housing units and the economic context in which they are traded.<br>
# <br>
#
#
# ###**Dataset 1: The Core Dataset**
# This dataset forms the foundation of our regression analysis. It contains granular transaction data from 1990 to the present, including Price, Floor Area, Flat Type, and Lease Commencement Date.
#
# We chose this dataset as it provides the Dependent Variable (Resale Price) essential for training our predictive model.
#
# Source: [Resale Flat Prices](https://data.gov.sg/datasets?query=Resale+Flat+Prices&resultId=d_8b84c4ee58e3cfc0ece0d773c8ca6abc)
#
# ###**Dataset 2: Physical Building Details**
# The core transaction data lacks specific structural metadata necessary for a granular assessment. Therefore, we chose this dataset as it offers a structural profile for every HDB block in Singapore, including critical features such as "Year Completed," "Max Floor Level," and "Total Dwelling Units."
#
# By merging this with the core dataset, we can engineer high-value features such as Remaining Lease and Storey Range (e.g., differentiating high-rise premiums), thereby significantly improving prediction accuracy.
#
# Source: [HDB Property Information](https://data.gov.sg/datasets?query=HDB+Property+Information&resultId=d_17f5382f26140b1fdae0ba2ef6239d2f)
#
# ###**Dataset 3: Transport Accessibility**
# In Singapore’s dense urban fabric, connectivity is a primary driver of real estate value. We chose this dataset as this provides the precise geospatial coordinates of all MRT station exits across the island.
#
# Therefore, this allows us to calculate the walking distance (in km) between a target HDB block and the nearest MRT, quantifying the convenience of accessibility to the nearest MRT.
#
# Source: [LTA MRT Station Exit (GeoJSON)](https://data.gov.sg/datasets?query=LTA+MRT+Station+Exit&resultId=d_b39d3a0871985372d7e1637193335da5)
#
#
# ###**Dataset 4: Education Accessibility**
# Proximity to educational institutions, particularly the "1km radius" rule for primary school registration, exerts strong pressure on housing demand. The dataset contains the official addresses and postal codes for all Primary, Secondary, and Junior College institutions.
#
# This enables the creation of a "School Proximity" feature, quantifying the distance to the nearest educational institution.
#
# Source: [General information of schools](https://data.gov.sg/datasets?query=General+Information+of+Schools&resultId=d_688b934f82c1059ed0a6993d2a829089)
#
#
# ###**Dataset 5: Economic Context**
# Comparing a flat sold in 2010 to one sold in 2024 requires adjusting for the changing value of money. This dataset inludes the weighted average change in prices of a basket of consumer goods and services, serving as a key information for inflation.
#
# We intend to use this dataset to adjust our model according to inflation rates allowing for a fair comparison of value across different economic eras.
#
# Source: [Consumer Price Index - Singstat](https://tablebuilder.singstat.gov.sg/table/TS/M213751)
#
#
# ###**Dataset 6: Geospatial Mapping**
# To bridge the gap between textual addresses and mathematical distance calculations, we leverage dynamic API integration. This API offers the most accurate geocoding services available.
#
# We chose this dataset to satisfy the requirement for data engineering skills. We inten to utilize the Search API to convert HDB street addresses (e.g., "Block 105 Ang Mo Kio") into coordinates, enabling the precise distance calculations required for the transport and education features.
#
# Source: [OneMap API](https://www.onemap.gov.sg/apidocs/maps)

# %% [markdown]
# In the data profiling process, we will outline the sources above and justify our final source selection.

# %% [markdown]
# # **Importing Modules**
# We import standard data manipulation and visualization libraries required for our analysis.
# Since we are working with MRT spatial data (Dataset 3), we also import the geopandas library to properly parse and handle GeoJSON files.

# %%
# !pip install pmdarima

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from statsmodels.tsa.stattools import adfuller
import pmdarima as pm
from statsmodels.tsa.statespace.sarimax import SARIMAX
from scipy.stats import skew
from scipy import stats
import statsmodels.api as sm
import warnings


warnings.filterwarnings('ignore')
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# For each dataset we gathered, we will conduct an initial phase of **Structural Data Profiling**. The primary objective at this stage is to audit the health, completeness, and formatting of the raw data before any feature engineering takes place.
#
# ### Based on our requirements analysis, this initial profiling will systematically identify:
#
# 1. **Basic Dataset Architecture**
#    * Number of rows and columns (Shape)
#    * Column names and data types
#    * Temporal boundaries (Date range for time-series and transaction data)
# 2. **Data Completeness**
#    * Identification and quantification of Null/NaN values per column
# 3. **Data Verification**
#    * A sample of the dataset (first few rows) to ensure values loaded with the correct parsing.
#
# *Note: The implementation of these steps may vary slightly to accommodate the individual characteristics of our diverse sources (e.g., verifying coordinate reference systems for spatial GeoJSON data vs. standardizing temporal axes for macroeconomic data).*
#
# **Rationale for Profiling Scope:**
# During this specific step, we have deliberately excluded conventional statistical profiling (such as measures of central tendency, variance, and outlier detection). Because our datasets range from macro-level economic indicators (CPI) to granular spatial data (MRT locations) and property transactions, applying blanket statistical profiling at the loading stage is ineffective.
#
# Instead, identifying distributions, analyzing natural market fluctuations, and treating specific outliers (e.g., "million-dollar" HDB flats) will be strictly reserved for the **Exploratory Data Analysis (EDA)** phase, where statistical measures can be applied contextually to the consolidated dataset.

# %% [markdown]
# # **Data Profiling**

# %% [markdown]
# ## **Dataset 1 (DS1)**
#
# Dataset 1 obtained from the Singapore Government's open data portal (Data.gov.sg), provides a comprehensive record of public housing resale transactions in Singapore. We intend to use this dataset as our primary target variable to predict housing prices. Before formally integrating this dataset into our study, we conducted structural data profiling.

# %%
ds1 = pd.read_csv("/content/Dataset 1.csv")
print("Basic Dataset Info")
print(f"Rows: {ds1.shape[0]}")
print(f"Columns: {ds1.shape[1]}")
print(f"Column Names: {ds1.columns.tolist()}")
print(f"Range of dates for Historical data: {ds1['month'].min()} to {ds1['month'].max()}")
# Out:
# Basic Dataset Info
# Rows: 224220
# Columns: 11
# Column Names: ['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range', 'floor_area_sqm', 'flat_model', 'lease_commence_date', 'remaining_lease', 'resale_price']
# Range of dates for Historical data: 2017-01 to 2026-01

# %% [markdown]
# DS1 contains a massive total of 224,220 rows, and 11 columns spanning various intrinsic attributes of HDB flats (e.g., floor area, lease data). Historical data for this dataset spans nearly a decade from January 2017 to January 2026, sorted chronologically by month.
# It is worth noting that some columns contain highly granular string formats that will require cleaning before they are usable in a machine learning model, such as the `remaining_lease` column showing text representations (e.g., "61 years 04 months"). Our primary goal for this dataset is to serve as the baseline timeline and target variable (`resale_price`) for our predictions.

# %%
counts = ds1['flat_type'].value_counts().sort_values(ascending=False)
total = counts.sum()

fig, ax = plt.subplots(figsize=(10, 6))

palette = sns.color_palette("Set2", len(counts))
bars = ax.bar(counts.index, counts.values, color=palette, edgecolor='white', linewidth=0.8)

ax.set_title('HDB Resale Flat Type Distribution', fontsize=15, fontweight='bold')
ax.set_xlabel('Flat Type')
ax.set_ylabel('Number of Transactions')
ax.set_ylim(0, counts.max() * 1.15)
ax.tick_params(axis='x', rotation=30)
ax.grid(axis='y', linestyle='--', alpha=0.5)
ax.spines[['top', 'right']].set_visible(False)

for bar, val in zip(bars, counts.values):
    pct = val / total * 100
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + counts.max() * 0.02,
        f'{val:,}\n({pct:.1f}%)',
        ha='center', va='bottom', fontsize=9, fontweight='bold'
    )

plt.tight_layout()
plt.savefig('flat_type_distribution.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# We are particularly interested in seeing the distribution of standard housing types. Data profiling helps us determine the volume of popular property types. We found that 95,072 rows belong specifically to 4 ROOM flat transactions, taking up a very substantial chunk of the dataset. This ensures we have deep statistical significance across property categories.

# %%
print("\nNull Values Per Column")
print(ds1.isnull().sum())
print(f"Percentage of null values: \n{(ds1.isnull().sum())/(ds1.shape[0])*100}")
# Out:
# Null Values Per Column
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# remaining_lease        0
# resale_price           0
# dtype: int64
# Percentage of null values:
# month                  0.0
# town                   0.0
# flat_type              0.0
# block                  0.0
# street_name            0.0
# storey_range           0.0
# floor_area_sqm         0.0
# flat_model             0.0
# lease_commence_date    0.0
# remaining_lease        0.0
# resale_price           0.0
# dtype: float64

# %% [markdown]
# It is highly important to ascertain if there are any null values in the dataset. Based on the output, there are absolutely no missing values out of a quarter-million rows, which is exceptionally promising for the integrity of our target variable.

# %%
print("\nSample Data")
ds1_sample = ds1[ds1['flat_type'] == '4 ROOM']
print(ds1_sample.head())
# Out:
# Sample Data
#       month        town flat_type block        street_name storey_range  \
# 33  2017-01  ANG MO KIO    4 ROOM   472  ANG MO KIO AVE 10     10 TO 12
# 34  2017-01  ANG MO KIO    4 ROOM   475  ANG MO KIO AVE 10     07 TO 09
# 35  2017-01  ANG MO KIO    4 ROOM   629   ANG MO KIO AVE 4     01 TO 03
# 36  2017-01  ANG MO KIO    4 ROOM   546  ANG MO KIO AVE 10     01 TO 03
# 37  2017-01  ANG MO KIO    4 ROOM   131   ANG MO KIO AVE 3     01 TO 03
#
#     floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 33            92.0  New Generation                 1979  61 years 06 months
# 34            91.0  New Generation                 1979  61 years 06 months
# 35            94.0  New Generation                 1981  63 years 09 months
# 36            92.0  New Generation                 1981            63 years
# 37            98.0  New Generation                 1979   61 years 01 month
#
#     resale_price
# 33      400000.0
# 34      400000.0
# ...

# %% [markdown]
# Visualizing the sample data, specifically the dominant 4-ROOM flat category allows us to critically evaluate the suitability of DS1 for our predictive pipeline.
#
# ### **Strengths**
#
# * **Statistical Power vs. Distributional Skew**: The immense volume of over 224,000 transaction records provides profound statistical confidence for our predictive modelling. However, because the dataset is heavily concentrated in standard flat types (e.g., 4-ROOM), our algorithm will naturally optimize its weights for this majority class, potentially reducing predictive accuracy for minority outliers (like 1-ROOM or Multi-Generation flats).
#
# * **Target Variable Integrity**: The dataset boasts impeccable completeness with zero missing values. This is exceptionally advantageous, as it guarantees we do not need to perform synthetic imputation on our dependent variable (`resale_price`), thereby preserving the authentic, uncorrupted variance of the housing market.
#
# ### **Limitations**
#
# * **Feature Engineering Prerequisites**: Critical baseline attributes, such as storey_range and remaining_lease, are natively recorded as granular text strings. In this categorical state, they are mathematically unreadable by regression algorithms. We are required to perform rigorous structural transformations to convert these strings into continuous numeric variables (e.g., transforming a lease string into a floating-point decimal) so the model can calculate linear depreciation.
#
# * **Temporal Price Distortion**: The most severe limitation of this raw dataset is its susceptibility to temporal bias. The listed transaction prices span nearly a decade but do not inherently factor in the time value of money. Using the raw resale_price would force the model to conflate macroeconomic inflation with genuine real estate appreciation, explicitly necessitating a mandatory merger with our CPI dataset (DS5) to normalize historical valuations.

# %% [markdown]
# ## **Dataset 2 (DS2)**
# Dataset 2 obtained from Data.gov.sg, provides a comprehensive directory of HDB Property Information across Singapore. We intend to use this dataset to supplement our transaction data with intrinsic property attributes (such as the year the block was completed and the presence of commercial facilities). Before determining whether we were to use this dataset, we conducted data profiling.

# %%
ds2 = pd.read_csv("/content/Dataset 2.csv")
print("Basic Dataset Info")
print(f"Rows: {ds2.shape[0]}")
print(f"Columns: {ds2.shape[1]}")
print(f"Column Names: {ds2.columns.tolist()}")
print(f"Range of years for Historical data (Year Completed): {ds2['year_completed'].min()} to {ds2['year_completed'].max()}")
# Out:
# Basic Dataset Info
# Rows: 13267
# Columns: 24
# Column Names: ['blk_no', 'street', 'max_floor_lvl', 'year_completed', 'residential', 'commercial', 'market_hawker', 'miscellaneous', 'multistorey_carpark', 'precinct_pavilion', 'bldg_contract_town', 'total_dwelling_units', '1room_sold', '2room_sold', '3room_sold', '4room_sold', '5room_sold', 'exec_sold', 'multigen_sold', 'studio_apartment_sold', '1room_rental', '2room_rental', '3room_rental', 'other_room_rental']
# Range of years for Historical data (Year Completed): 1937 to 2025

# %% [markdown]
# DS2 contains a total of 13,267 rows, and 24 columns spanning a multi-dimensional view of HDB block metrics. Historical data for this dataset spans block completion years from 1937 to 2025.
# It is worth noting that some columns, such as specific room rental breakdowns (e.g., `1room_rental`, `other_room_rental`), contain attributes that are not directly relevant to our investigation of predicting flat resale prices. Our goal for this dataset is to gain insight into structural block attributes like maximum floor level and the presence of nearby amenities.

# %%
commercial_count = ds2[ds2['commercial'] == 'Y'].shape[0]
print(f"Commercial facility data: {commercial_count}")
# Out:
# Commercial facility data: 2520

# %% [markdown]
# We also are particularly interested in blocks that offer mixed-use convenience, such as having commercial spaces. Data profiling helps us in finding out how much of this specific data is available. We find that 2,520 rows of commercial-equipped block data is available, quite a substantial number still. However, this contains both needed and unnecessary data for our requirements, e.g. it still includes detailed rental statistics alongside the amenity flags.

# %%
print("\nNull Values Per Column")
print(ds2.isnull().sum())
print(f"Percentage of null values: \n{(ds2.isnull().sum())/(ds2.shape[0])*100}")
# Out:
# Null Values Per Column
# blk_no                   0
# street                   0
# max_floor_lvl            0
# year_completed           0
# residential              0
# commercial               0
# market_hawker            0
# miscellaneous            0
# multistorey_carpark      0
# precinct_pavilion        0
# bldg_contract_town       0
# total_dwelling_units     0
# 1room_sold               0
# 2room_sold               0
# 3room_sold               0
# 4room_sold               0
# 5room_sold               0
# exec_sold                0
# multigen_sold            0
# studio_apartment_sold    0
# 1room_rental             0
# 2room_rental             0
# 3room_rental             0
# other_room_rental        0
# dtype: int64
# Percentage of null values:
# blk_no                   0.0
# street                   0.0
# max_floor_lvl            0.0
# year_completed           0.0
# residential              0.0
# commercial               0.0
# market_hawker            0.0
# ...

# %% [markdown]
# It is also highly important to ascertain if there are any null values in the dataset. Based on the output, there is no missing values, which is promising.

# %%
print("\nSample Data")
ds2 = ds2[ds2['commercial'] == 'Y']
print(ds2.head())
# Out:
# Sample Data
#   blk_no             street  max_floor_lvl  year_completed residential  \
# 0      1           BEACH RD             16            1970           Y
# 2      1      CANTONMENT RD              2            2010           N
# 4      1  CHANGI VILLAGE RD              4            1975           Y
# 8      1         EVERTON PK             12            1965           Y
# 9      1      GEYLANG SERAI              2            2009           N
#
#   commercial market_hawker miscellaneous multistorey_carpark  \
# 0          Y             N             N                   N
# 2          Y             N             N                   N
# 4          Y             N             N                   N
# 8          Y             N             N                   N
# 9          Y             N             N                   N
#
#   precinct_pavilion  ... 3room_sold  4room_sold  5room_sold  exec_sold  \
# 0                 N  ...        138           1           2          0
# ...

# %% [markdown]
# Sample data, limiting blocks to those that contain commercial facilities, is visualised with the code above.
#
# ### **Strengths**
# * **Data Completeness & Amenity Proxies**: The dataset exhibits impeccable structural integrity with zero missing values. More importantly, its granular categorical flags (e.g., `market_hawker`, `multistorey_carpark`) act as high-value proxy variables for micro-level neighborhood desirability. Rather than relying purely on broad, macro-level town averages, these features allow our regression model to learn and assign discrete price premiums for localized, block-specific conveniences.
#
# ### **Limitations**
#
# * **High-Dimensional Noise**: In its raw state, the dataset is bloated with administrative variables (such as highly specific public rental unit counts) that are irrelevant to open-market valuation. Retaining these would introduce severe dimensionality issues, forcing the model to process mathematical noise. This strictly necessitates an aggressive filtering and dimensionality reduction phase before the data can be safely utilized.
#
# * **Spatial Blindness**: The most critical limitation of DS2 is its complete lack of mathematical spatial coordinates (Latitude/Longitude). In its native textual state, it is mathematically impossible to use this dataset to compute proximity to transit hubs or schools. This inherent spatial blindness explicitly mandates our downstream integration of dynamic API geocoding (Dataset 6) to bridge the gap between text addresses and continuous distance features.
#
# ### **Conclusion**
# Despite its spatial limitations and initial noise, DS2 remains an indispensable structural layer. By utilizing a deterministic relational merge via composite keys (block and street_name), we can seamlessly map these intrinsic architectural and amenity attributes onto our core transaction timeline (DS1). This establishes the foundational physical value of the flats before we introduce our spatial and macroeconomic adjustments.

# %% [markdown]
# ## **Dataset 3 (DS3)**
# Dataset 3 obtained from the Land Transport Authority (LTA) via Data.gov.sg, provides spatial coordinates for all MRT and LRT Station Exits across Singapore. We intend to use this dataset to calculate the urban accessibility of each HDB flat. Specifically, the walking distance to the nearest MRT station. Before integrating this spatial data, we conducted data profiling.

# %%
ds3 = gpd.read_file("/content/Dataset 3.geojson")
print("Basic Dataset Info")
print(f"Rows: {ds3.shape[0]}")
print(f"Columns: {ds3.shape[1]}")
print(f"Column Names: {ds3.columns.tolist()}")
print(f"Range of years for Historical data: N/A (Static Spatial Data, Last Updated: {ds3['FMEL_UPD_D'].max()[:4]})")
# Out:
# Basic Dataset Info
# Rows: 597
# Columns: 6
# Column Names: ['OBJECTID', 'STATION_NA', 'EXIT_CODE', 'INC_CRC', 'FMEL_UPD_D', 'geometry']
# Range of years for Historical data: N/A (Static Spatial Data, Last Updated: 2025)

# %% [markdown]
# DS3 contains a total of 597 rows, and 6 columns providing exact point coordinates for transport infrastructure. Unlike our transaction datasets, this dataset does not have historical time-series data; rather, it is a static snapshot of the MRT network's current state.
# It is worth noting that some columns, such as `OBJECTID`, `INC_CRC`, and `FMEL_UPD_D` (Update Date), contain administrative database attributes that are not directly relevant to our investigation. Our primary goal for this dataset is to extract the `STATION_NA` (Station Name) and the geometry (Latitude/Longitude coordinates) to engineer a proximity feature for our resale flats.

# %%
unique_station_count = ds3['STATION_NA'].nunique()
print(f"Unique MRT/LRT Stations data: {unique_station_count}")
# Out:
# Unique MRT/LRT Stations data: 186

# %% [markdown]
# Because this dataset lists every individual *exit*, a single station will have multiple rows (e.g., Dhoby Ghaut MRT has several exits). Data profiling helps us find out the actual number of distinct train stations available. We find that the 597 exits map back to exactly 186 unique MRT and LRT stations across the island. We will need to decide whether to calculate distance to the nearest *exit* or aggregate these points to find the central coordinate of the *station*.

# %%
print("\nNull Values Per Column")
print(ds3.isnull().sum())
print(f"Percentage of null values: \n{(ds3.isnull().sum())/(ds3.shape[0])*100}")
# Out:
# Null Values Per Column
# OBJECTID      0
# STATION_NA    0
# EXIT_CODE     0
# INC_CRC       0
# FMEL_UPD_D    0
# geometry      0
# dtype: int64
# Percentage of null values:
# OBJECTID      0.0
# STATION_NA    0.0
# EXIT_CODE     0.0
# INC_CRC       0.0
# FMEL_UPD_D    0.0
# geometry      0.0
# dtype: float64

# %% [markdown]
# It is also highly important to ascertain if there are any null values in the dataset. Based on the output, there are no missing values, meaning every single exit has a valid recorded spatial coordinate.

# %%
print("\nSample Data")
ds3_sample = ds3[ds3['STATION_NA'] == 'BRIGHT HILL MRT STATION']
print(ds3_sample.head())
# Out:
# Sample Data
#    OBJECTID               STATION_NA EXIT_CODE           INC_CRC  \
# 0     17885  BRIGHT HILL MRT STATION    Exit 1  CFB9350F44E8991A
# 1     17886  BRIGHT HILL MRT STATION    Exit 2  F273E9D550B06062
# 2     17887  BRIGHT HILL MRT STATION    Exit 4  BC4A442B12F99E85
# 3     17888  BRIGHT HILL MRT STATION    Exit 3  2A45076ED986B275
#
#        FMEL_UPD_D                   geometry
# 0  20251202172807  POINT (103.83364 1.36404)
# 1  20251202172807  POINT (103.83351 1.36328)
# 2  20251202172807  POINT (103.83195 1.36316)
# 3  20251202172807  POINT (103.83238 1.36218)

# %% [markdown]
# Sample data, limiting to the exits belonging to Bright Hill MRT Station, is visualised with the code above.
#
# ### **Strengths**
#
# * **Spatial Precision & Data Completeness**: The dataset exhibits perfect structural integrity with zero missing coordinate points. Furthermore, its native geospatial format provides immense micro-level granularity, mapping the precise physical locations of every station exit rather than assigning a vague, singular point to an entire transit hub. This uncorrupted precision is incredibly advantageous, as transit convenience is widely considered one of the heaviest determining weights in Singaporean property valuation.
#
# ### **Limitations**
#
# * **Algorithmic Efficiency vs. Micro-Granularity**: While the exit-level granularity is precise, it introduces a severe computational hurdle. Calculating the distance between 224,000 historical transactions and every individual MRT exit across the island is computationally exhaustive. Furthermore, keeping separate exits as unique data points risks introducing multicollinearity into our model, as multiple exits from the same station will produce highly correlated distance metrics. Therefore, a strict analytical trade-off is required: we must mathematically aggregate these individual exits into singular station "centroids." While this grouping sacrifices a tiny fraction of micro-level pedestrian accuracy, it drastically optimizes the algorithm's processing efficiency and prevents feature bloat.
#
# * **Dimensionality Constraints**: In its raw state, the dataset carries administrative metadata (e.g., INC_CRC, FMEL_UPD_D) and requires specialized spatial libraries (geopandas) to parse. Because these administrative tags hold zero predictive weight regarding house prices, they represent mathematical noise and must be systematically dropped before the coordinates are extracted into standard continuous floats.
#
# ### **Conclusion**
# Despite the necessity for spatial aggregation and dimensionality reduction, DS3 remains an indispensable geospatial layer. The coordinate mapping it provides is an absolute prerequisite for generating the proximity metrics that allow our regression model to quantify locational utility.

# %% [markdown]
# ## **Dataset 4 (DS4)**
# Dataset 4 obtained from the Ministry of Education (MOE) via Data.gov.sg, provides a comprehensive directory of all educational institutions across Singapore. We intend to use this dataset to calculate the urban accessibility and desirability of each HDB flat. Specifically, the proximity to primary schools, which is a known driver of property valuation. Before integrating this dataset, we conducted structural data profiling.

# %%
ds4 = pd.read_csv("/content/Dataset 4.csv")
print("Basic Dataset Info")
print(f"Rows: {ds4.shape[0]}")
print(f"Columns: {ds4.shape[1]}")
print(f"Column Names: {ds4.columns.tolist()}")
print(f"Range of years for Historical data: N/A (Static Infrastructure Directory)")
# Out:
# Basic Dataset Info
# Rows: 337
# Columns: 31
# Column Names: ['school_name', 'url_address', 'address', 'postal_code', 'telephone_no', 'telephone_no_2', 'fax_no', 'fax_no_2', 'email_address', 'mrt_desc', 'bus_desc', 'principal_name', 'first_vp_name', 'second_vp_name', 'third_vp_name', 'fourth_vp_name', 'fifth_vp_name', 'sixth_vp_name', 'dgp_code', 'zone_code', 'type_code', 'nature_code', 'session_code', 'mainlevel_code', 'sap_ind', 'autonomous_ind', 'gifted_ind', 'ip_ind', 'mothertongue1_code', 'mothertongue2_code', 'mothertongue3_code']
# Range of years for Historical data: N/A (Static Infrastructure Directory)

# %% [markdown]
# DS4 contains a total of 337 rows (representing individual schools), and 31 columns detailing school characteristics, administrative contacts, and locations. Like our MRT dataset, this is a static cross-sectional dataset rather than a historical time-series.
# It is worth noting that a vast majority of the columns, such as principal and vice-principal names (e.g., `principal_name`, `first_vp_name`), contact details, and bus descriptions, are administrative attributes entirely irrelevant to our spatial modeling. Our primary goal for this dataset is to extract the school's location (using the address or `postal_code`) and filter the institutions based on their academic level (`mainlevel_code`).

# %%
primary_school_count = ds4[ds4['mainlevel_code'] == 'PRIMARY'].shape[0]
print(f"Primary School data: {primary_school_count}")
# Out:
# Primary School data: 179

# %% [markdown]
# We are particularly interested in the locations of Primary Schools, as the Primary 1 (P1) registration framework in Singapore strongly prioritizes home-to-school distances, directly inflating the value of nearby HDB properties. Data profiling helps us isolate this specific academic level. We find that out of the 337 institutions, exactly 179 rows belong to Primary Schools.

# %%
print("\nNull Values Per Column")
print(ds4.isnull().sum())
print(f"Percentage of null values: \n{(ds4.isnull().sum())/(ds4.shape[0])*100}")
# Out:
# Null Values Per Column
# school_name           0
# url_address           0
# address               0
# postal_code           0
# telephone_no          0
# telephone_no_2        0
# fax_no                0
# fax_no_2              0
# email_address         0
# mrt_desc              0
# bus_desc              0
# principal_name        0
# first_vp_name         0
# second_vp_name        0
# third_vp_name         1
# fourth_vp_name        0
# fifth_vp_name         0
# sixth_vp_name         0
# dgp_code              0
# zone_code             0
# type_code             0
# nature_code           0
# session_code          0
# mainlevel_code        0
# sap_ind               0
# autonomous_ind        0
# gifted_ind            0
# ip_ind                0
# mothertongue1_code    0
# mothertongue2_code    0
# mothertongue3_code    0
# dtype: int64
# Percentage of null values:
# school_name           0.000000
# url_address           0.000000
# address               0.000000
# ...

# %% [markdown]
# It is highly important to ascertain if there are any null values in the dataset. Based on the output, there is only 1 missing value across the entire dataset, located in the `third_vp_name` column. Because this is purely an administrative contact field that we intend to drop anyway, this negligible missing data will not impact our geospatial analysis.

# %%
print("\nSample Data")
ds4_sample = ds4[ds4['mainlevel_code'] == 'PRIMARY']
print(ds4_sample.head())
# Out:
# Sample Data
#                     school_name                            url_address  \
# 0      ADMIRALTY PRIMARY SCHOOL       https://admiraltypri.moe.edu.sg/
# 2  AHMAD IBRAHIM PRIMARY SCHOOL  http://www.ahmadibrahimpri.moe.edu.sg
# 4                AI TONG SCHOOL           http://www.aitong.moe.edu.sg
# 5      ALEXANDRA PRIMARY SCHOOL         http://alexandrapri.moe.edu.sg
# 6   ANCHOR GREEN PRIMARY SCHOOL   http://www.anchorgreenpri.moe.edu.sg
#
#                          address  postal_code telephone_no telephone_no_2  \
# 0         11 WOODLANDS CIRCLE          738907     63620598             na
# 2         10 YISHUN STREET 11          768643     67592906             na
# 4       100 Bright Hill Drive          579646     64547672             na
# 5  2A Prince Charles Crescent          159016     62485400             na
# 6         31 Anchorvale Drive          544969     68861356             na
#
#      fax_no fax_no_2              email_address  \
# ...

# %% [markdown]
# Sample data, specifically limiting schools to the Primary academic level, is visualised with the code above.
#
# ### **Strengths**
#
# * **Domain-Specific Signal Extraction**: The dataset’s clean categorical variables (e.g., mainlevel_code) allow us to isolate Primary Schools flawlessly. This is an analytically vital filtering step because the Ministry of Education’s strict "1km radius" Primary 1 registration framework generates severe, localized price premiums. By excluding Secondary and Tertiary institutions—which do not exert the same localized boundary pressure—we ensure our regression model learns a highly specific and accurate "school premium" weight.
#
# * **Data Completeness**: The dataset exhibits near-perfect structural integrity. This ensures that the baseline postal codes are fully intact, preventing the need for synthetic data imputation before our spatial engineering phase.
#
# ### **Limitations**
#
# * **Spatial Blindness & API Dependency**: In its native state, this dataset suffers from complete spatial blindness. Postal codes and text addresses are categorical strings; a regression algorithm cannot mathematically compute the distance between "738907" and an HDB block. This explicitly mandates our downstream integration with the OneMap API (Dataset 6) to transform these text strings into continuous geographic coordinates (Latitude/Longitude).
#
# * **High-Dimensional Noise**: The dataset contains 31 columns, the vast majority of which are administrative bloat (e.g., phone numbers, web addresses, and fax numbers). To prevent signal dilution and protect the algorithm from processing meaningless data, a strict dimensionality reduction phase is required to strip the dataset down to just the institution names and their locations.
#
# * **Temporal Survivorship Bias**: A critical limitation of this dataset is that it represents a contemporary snapshot of the education landscape. Applying current school locations to historical resale transactions (e.g., from 2017) introduces survivorship bias. The model will retroactively apply proximity premiums for newly built schools while remaining blind to schools that have since relocated or merged.
#
# ### **Conclusion**
# Despite the inherent temporal bias and heavy reliance on external API geocoding, extracting these Primary School locations is mathematically indispensable. They serve as the foundational spatial nodes required to compute the localized education premiums that heavily dictate Singaporean real estate valuation.

# %% [markdown]
# ## **Dataset 5 (DS5)**
# Dataset 5 obtained from the Singapore Department of Statistics (SingStat), provides macroeconomic data in the form of the Consumer Price Index (CPI). We intend to use this dataset to adjust the historical resale prices for inflation, allowing our predictive model to accurately value money over our nearly ten-year timeline. Before determining whether we were to use this dataset, we conducted structural data profiling.

# %%
# Added sheet_name='T6' to target the correct monthly data tab
ds5 = pd.read_excel("/content/Dataset 5.xlsx", sheet_name='T6', skiprows=10)

# We drop the bottom rows that contain administrative footnotes (which lack CPI data)
ds5 = ds5.dropna(subset=['2025 Dec'])

print("Basic Dataset Info")
print(f"Rows: {ds5.shape[0]}")
print(f"Columns: {ds5.shape[1]}")
# Slicing the column names output so it doesn't flood the console with 700+ dates
print(f"Column Names: {ds5.columns.tolist()[:5]} ... {ds5.columns.tolist()[-5:]}")
print(f"Range of dates for Historical data: {ds5.columns[-1]} to {ds5.columns[1]}")
# Out:
# Basic Dataset Info
# Rows: 207
# Columns: 781
# Column Names: ['Data Series', '2025 Dec', '2025 Nov', '2025 Oct', '2025 Sep'] ... ['1961 May', '1961 Apr', '1961 Mar', '1961 Feb', '1961 Jan']
# Range of dates for Historical data: 1961 Jan to 2025 Dec

# %% [markdown]
# DS5 contains a total of 207 rows (representing various consumer goods and services categories), and an immense 781 columns spanning monthly CPI measurements. Historical data spans from January 1961 to December 2025.
# It is worth noting that this dataset is currently in a "wide" pivoted format where the temporal data points are spread across columns rather than rows. Our goal for this dataset is to extract the general inflation rate and map it chronologically to our HDB resale transaction data.

# %%
all_items_count = ds5[ds5['Data Series'].str.contains('All Items', na=False)].shape[0]
print(f"All Items (General CPI) data: {all_items_count}")
# Out:
# All Items (General CPI) data: 3

# %% [markdown]
# We are specifically interested in the overall macroeconomic inflation rather than highly specific individual goods (e.g., "Food" or "Transport"). Data profiling helps us quickly isolate the general baseline metric. We found that exactly 1 row corresponds to the overarching "All Items" general CPI index, which is exactly what we need to standardise our resale transaction prices.

# %%
print("\nNull Values Per Column")
print(ds5.isnull().sum().head(5)) # Showing first 5 for readability
print(f"Percentage of null values: \n{(ds5.isnull().sum().head(5))/(ds5.shape[0])*100}")
# Out:
# Null Values Per Column
# Data Series    0
# 2025 Dec       0
# 2025 Nov       0
# 2025 Oct       0
# 2025 Sep       0
# dtype: int64
# Percentage of null values:
# Data Series    0.0
# 2025 Dec       0.0
# 2025 Nov       0.0
# 2025 Oct       0.0
# 2025 Sep       0.0
# dtype: float64

# %% [markdown]
# It is also highly important to ascertain if there are any null values in the dataset. Based on the native pandas output, there are 0 missing NaN values. However, manual inspection reveals that missing older historical values are recorded as the string 'na' rather than a true null, meaning we will need to handle these string placeholders manually during data cleaning.

# %%
print("\nSample Data")
ds5_sample = ds5[ds5['Data Series'].str.contains('All Items', na=False)]
print(ds5_sample.iloc[:, :6]) # Limiting to the first 6 columns for visual readability
# Out:
# Sample Data
#                                     Data Series  2025 Dec  2025 Nov  2025 Oct  \
# 0                                     All Items   101.854   101.579   101.330
# 205                All Items Less Accommodation   101.888   101.533   101.827
# 206  All Items Less Imputed Rentals For Housing   102.164   101.824   101.516
#
#      2025 Sep  2025 Aug
# 0     101.320   100.963
# 205   101.216   100.732
# 206   101.508   101.055

# %% [markdown]
# Sample data, specifically limiting the row to the 'All Items' macro-index, is visualised with the code above.
#
# ### **Strengths**
#
# * **Macroeconomic Normalization**: The most significant strength of this dataset is its capacity to cure the inherent temporal bias within our core transaction data (DS1). By providing a verified, month-by-month Consumer Price Index (CPI) dating back to 1961, it perfectly covers our entire transaction timeline. This allows us to engineer a "Real Resale Price" target variable, mathematically forcing the regression model to differentiate between genuine asset appreciation and baseline currency inflation.
#
# ### **Limitations**
#
# * **Relational Incompatibility**: In its native state, this dataset is published in a "wide" matrix format (where hundreds of months act as individual column headers). This structure is relationally incompatible with our transaction logs. To utilize this data, we must perform a computationally heavy pd.melt() operation to transpose the matrix into a "long" time-series format. This is not merely a formatting preference; it is a structural necessity to establish the composite joining keys (Year and Month) required to merge the inflation metrics onto DS1.
#
# * **Dimensional Noise**: The dataset tracks 206 highly specific sub-categories of inflation (e.g., "Clothing", "Recreation"). Retaining these micro-indices would introduce severe dimensional noise into our model. We must aggressively filter the data to retain only the overarching "All Items" index to prevent the algorithm from attempting to correlate HDB prices with irrelevant consumer goods.
#
# * **Data Type Corruption**: The dataset encodes empty historical values as the text string 'na' rather than standard nulls (NaN). If left untreated, this corrupts the entire column's data type, preventing the continuous float calculations necessary for regression. A strict type-coercion step is required before the data can be parsed.
#
# ### **Conclusion**
# Despite the rigorous structural reshaping, dimensionality reduction, and type-coercion required, DS5 remains an indispensable economic layer. Without standardizing our target variable against historical inflation, any time-series predictive pricing model would be fundamentally mathematically flawed.

# %% [markdown]
# ## **Dataset 6 (DS6) - OneMap API Geocoding**
# DS6 is not a static file, but rather a dynamic data stream obtained from the Singapore Land Authority's (SLA) OneMap API. We intend to use this API to bridge the spatial data gaps in our other datasets (specifically DS2 and DS4), converting raw HDB addresses and school postal codes into precise Latitude and Longitude coordinates. Before integrating this API into our data pipeline, we conducted functional data profiling.

# %%
import requests
import time
import pandas as pd

def get_coordinates(postal_code):
    """
    Get lat/long from OneMap API using postal code
    """
    url = f"https://www.onemap.gov.sg/api/common/elastic/search"
    params = {
        'searchVal': postal_code,
        'returnGeom': 'Y',
        'getAddrDetails': 'Y'
    }

    try:
        response = requests.get(url, params=params)
        data = response.json()

        if data['found'] > 0:
            result = data['results'][0]
            return {
                'latitude': float(result['LATITUDE']),
                'longitude': float(result['LONGITUDE']),
                'address': result['ADDRESS']
            }
        else:
            return None
    except:
        return None

print("Basic Dataset (API) Info")
print(f"Format: JSON Response Stream")
print(f"Key Extracted Fields: ['latitude', 'longitude', 'address']")
print(f"Temporal Range: Real-time (Always current)")
# Out:
# Basic Dataset (API) Info
# Format: JSON Response Stream
# Key Extracted Fields: ['latitude', 'longitude', 'address']
# Temporal Range: Real-time (Always current)

# %% [markdown]
# DS6 acts as a spatial transformer. Instead of having a fixed number of rows and columns, its volume is dictated entirely by our input queries. By passing parameters to the endpoint, we dynamically extract a dictionary containing exactly 3 target keys: latitude, longitude, and the standardized address.
# It is worth noting that while the raw API returns a massive amount of metadata (like building names and block numbers), our custom function deliberately filters out the noise to return only the specific variables required to engineer our distance features.

# %%
# Testing API robustness and null handling
print("\nAPI Response & Null Value Handling Test")

valid_test = get_coordinates("520123")
invalid_test = get_coordinates("000000")

print(f"Valid Postal (520123) Response: {valid_test is not None}")
print(f"Invalid Postal (000000) Response: {invalid_test}")
# Out:
# API Response & Null Value Handling Test
# Valid Postal (520123) Response: True
# Invalid Postal (000000) Response: None

# %% [markdown]
# For dynamic APIs, measuring "null values" means testing how the function handles bad data. Our profiling verifies that the API safely returns a precise None type (which translates to a Null/NaN in pandas) when fed an invalid or non-existent postal code, preventing our pipeline from crashing during mass iterations.

# %%
print("\nSample Data Output")
# Creating a mock dataframe from a few API calls to visualize the final structure
sample_postals = ["738907", "768643"] # Admiralty Pri, Ahmad Ibrahim Pri
results = [get_coordinates(p) for p in sample_postals]
ds6_sample = pd.DataFrame(results)
ds6_sample.insert(0, 'input_postal', sample_postals)

print(ds6_sample)
# Out:
# Sample Data Output
#   input_postal  latitude   longitude  \
# 0       738907  1.442635  103.800040
# 1       768643  1.433153  103.832942
#
#                                              address
# 0  11 WOODLANDS CIRCLE ADMIRALTY PRIMARY SCHOOL S...
# 1  10 YISHUN STREET 11 AHMAD IBRAHIM PRIMARY SCHO...

# %% [markdown]
# Sample data, simulated by passing two school postal codes from DS4 into the API, is visualised with the code above.
#
# With this, we are able to evaluate the pros and cons of DS6 (OneMap API):
#
# ### **Strengths**
#
# * **Authoritative Spatial Translation**: The primary strength of DS6 is its role as a necessary mathematical bridge. Regression models cannot process categorical text strings (e.g., "Block 105 Ang Mo Kio"); they require continuous numerical vectors. By querying this highly authoritative SLA endpoint, we seamlessly translate raw textual addresses into the precise Latitude and Longitude coordinate space required to compute our core Haversine proximity features.
#
# ### **Limitations**
#
# * **Temporal Asymmetry & Survivorship Bias**: The most critical limitation of using a live API is that it queries the contemporary topography of Singapore. Consequently, applying this current map to historical resale data (dating back to 2017) creates spatial blind spots. Buildings or infrastructure that have been demolished, renamed, or reclassified since their transaction date will fail to geocode (returning None). To protect the integrity of the distance algorithm, we must deliberately drop these failed rows. While this prevents synthetic spatial corruption, it forces a trade-off: our model inherently suffers from a minor survivorship bias, losing a fraction of its historical transaction volume.
#
# * **Computational Bottlenecks & Pipeline Constraints**: Unlike static CSV files, integrating a live API introduces severe network dependency and I/O latency. Iterating this query over thousands of unique HDB blocks requires a stable connection and exposes the pipeline to server-side rate limiting. To prevent our IP from being temporarily blocked by the SLA servers, we are required to hardcode intentional throttling (time.sleep()) into our iterative loops. This establishes a strict trade-off, sacrificing data preparation speed for API stability and absolute spatial accuracy.
#
# ### **Conclusion**
# Despite the severe computational latency and the minor survivorship bias introduced by missing historical data, integrating the OneMap API is an absolute necessity. It is the only reliable, automated methodology to construct the foundational spatial vectors required to evaluate urban accessibility within our predictive model.

# %% [markdown]
# # **Data Preparation**
# While we have ascertained our datasets are suitable for our investigation, it is still essential to prepare our data for meaningful analysis and modeling. Careful processing is necessary to parse the data of any unnecessary information, as well as standardise data formats into one suitable for our analysis across all our sources.

# %% [markdown]
# ## **DS1: HDB Resale Flat Prices**
# With the foundational data from DS1 established, our primary objective is to transform raw transaction logs into a machine-readable mathematical structure. A critical first step involves parsing the native month attribute (currently encoded as a categorical "YYYY-MM" string) into two distinct integer variables: Year and Month.
#
# While this appears to be a simple formatting task, decoupling these temporal components is analytically vital for our regression architecture. Standard machine learning algorithms cannot natively process datetime strings. By separating the data into discrete integers, we enable the model to isolate two entirely distinct economic signals: the macro-level annual price progression (Year) and the micro-level seasonal fluctuations in housing demand (Month). Furthermore, establishing these standardized integer columns is a strict relational prerequisite; without them, it would be mathematically impossible to execute the downstream time-series merge with our macroeconomic inflation data (Dataset 5).

# %%
# The 'month' attribute is parsed to extract the year and month
ds1[['Year', 'Month']] = ds1['month'].str.split('-', expand=True).astype(int)

# %% [markdown]
# Following the temporal extraction, we systematically drop the original categorical month string, alongside any other structurally obsolete attributes.
#
# While removing redundant columns natively optimizes the DataFrame's memory footprint, the primary motivation for this step is purely algorithmic. Retaining the original text columns alongside our newly engineered features (like `Year` and `Month`) introduces severe analytical risks. Specifically, passing both the raw string and the parsed integers into a regression model inflates the dataset's dimensionality without contributing any new predictive variance. This directly exposes the algorithm to multicollinearity where the model becomes confused by duplicate data points and risks distorting the final predictive weights. By strictly pruning these redundant features, we ensure our model trains exclusively on clean, independent mathematical signals.

# %%
ds1 = ds1.drop(columns=["month", "remaining_lease"])

# %% [markdown]
# The resulting DataFrame is presented below.

# %%
print(ds1)
# Out:
#               town  flat_type block        street_name storey_range  \
# 0       ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1       ANG MO KIO     3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2       ANG MO KIO     3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3       ANG MO KIO     3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4       ANG MO KIO     3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
# ...            ...        ...   ...                ...          ...
# 224215      YISHUN  EXECUTIVE   325        YISHUN CTRL     10 TO 12
# 224216      YISHUN  EXECUTIVE   325        YISHUN CTRL     04 TO 06
# 224217      YISHUN  EXECUTIVE   360     YISHUN RING RD     07 TO 09
# 224218      YISHUN  EXECUTIVE   643       YISHUN ST 61     10 TO 12
# 224219      YISHUN  EXECUTIVE   643       YISHUN ST 61     04 TO 06
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0                 44.0        Improved                 1979      232000.0
# ...

# %% [markdown]
# ## **DS2: HDB Property Information**
# With the transaction timeline established, our objective for DS2 is to isolate the intrinsic architectural and amenity features of each HDB block. By extracting critical structural vectors, such as maximum floor level and the year completed, we engineer the foundational attributes necessary to evaluate physical property depreciation and vertical space premiums. These extracted features will ultimately serve as the structural enrichment layer during our relational merge with the core resale transactions.
#
# To prepare this dataset for integration, we must execute a strict dimensionality reduction protocol. The raw directory is heavily bloated with granular administrative variables detailing specific subsidized rental and sold unit breakdowns. Retaining these columns would introduce severe algorithmic noise into our macro-level pricing model. Because subsidized public leasing metrics do not dictate open market valuation, forcing the algorithm to process them increases the risk of overfitting through spurious mathematical correlations. By aggressively dropping these extraneous columns, we protect the integrity of the model, ensuring its predictive weights are optimized strictly around the physical conveniences and architectural traits that genuinely drive real estate premiums.

# %%
ds2 = pd.read_csv("/content/Dataset 2.csv")

# Dropping granular unit breakdown columns
columns_to_drop = [
    '1room_sold', '2room_sold', '3room_sold', '4room_sold', '5room_sold',
    'exec_sold', 'multigen_sold', 'studio_apartment_sold',
    '1room_rental', '2room_rental', '3room_rental', 'other_room_rental'
]
ds2 = ds2.drop(columns=columns_to_drop)

# %% [markdown]
# Following the removal of administrative noise, we addressed the categorical amenity indicators (e.g., the presence of commercial spaces, multistorey carparks, or precinct pavilions) which were natively encoded as human-readable 'Y' or 'N' strings.
#
# While these alphabetical strings are easily interpreted during manual data profiling, they are mathematically inert. Regression algorithms cannot compute mathematical weights or gradients against text. To resolve this structural incompatibility, we executed a strict boolean encoding protocol, mapping these qualitative states into quantitative binary integers (1 and 0). This transformation is not merely a formatting preference; it is an algorithmic prerequisite. By converting a textual flag into a binary numerical vector, we empower the regression model to calculate and assign a discrete monetary coefficient to each amenity. This ensures the algorithm can mathematically capture and apply the exact price premium a buyer is willing to pay for block-level conveniences.

# %%
# Converting 'Y'/'N' categorical flags to binary integers
amenity_cols = ['residential', 'commercial', 'market_hawker', 'miscellaneous', 'multistorey_carpark', 'precinct_pavilion']
for col in amenity_cols:
    ds2[col] = ds2[col].map({'Y': 1, 'N': 0})

# %% [markdown]
# The resulting DataFrame is presented below.

# %%
print(ds2)
# Out:
#       blk_no             street  max_floor_lvl  year_completed  residential  \
# 0          1           BEACH RD             16            1970            1
# 1          1    BEDOK STH AVE 1             14            1975            1
# 2          1      CANTONMENT RD              2            2010            0
# 3          1       CHAI CHEE RD             15            1982            1
# 4          1  CHANGI VILLAGE RD              4            1975            1
# ...      ...                ...            ...             ...          ...
# 13262   998A      BUANGKOK CRES             18            2018            1
# 13263   998B      BUANGKOK CRES             17            2018            1
# 13264    999      BUANGKOK CRES              2            2018            0
# 13265   999A      BUANGKOK CRES             18            2018            1
# 13266   999B      BUANGKOK CRES             17            2018            1
#
# ...

# %% [markdown]
# ## **DS3: MRT Station Exits (Urban Accessibility)**
# With the raw spatial data from DS3 loaded, our objective is to construct a mathematical coordinate dictionary mapping every MRT and LRT station to a singular geographic point. This establishes the foundational spatial layer required to compute the transit proximity of any historical HDB transaction.
#
# During our initial data profiling, we identified a critical structural bottleneck. The raw GeoJSON natively records every individual physical station exit, resulting in 597 distinct coordinate rows. If we were to use this granular data natively, our proximity algorithm would redundantly calculate the distance to multiple separate exits for the exact same station. This computational bloat would severely degrade pipeline efficiency and risk introducing multicollinearity into our downstream regression model.
#
# To resolve this, we executed a strict spatial aggregation step. By parsing the GeoJSON to group coordinates under their respective `STATION_NA` labels, we effectively collapse the individual exits into a single mathematical centroid for each station. While this specific trade-off sacrifices a minor degree of micro-level pedestrian accuracy, it is absolutely essential. It protects the algorithm from redundant spatial vectors and drastically optimizes the processing speed required for our distance calculations.

# %%
import json

# Parsing the raw GeoJSON structure to extract attributes and point coordinates
with open('/content/Dataset 3.geojson', 'r') as f:
    data = json.load(f)

features = []
for f in data['features']:
    props = f['properties']
    coords = f['geometry']['coordinates'] # Returns [Longitude, Latitude]
    features.append({
        'STATION_NA': props['STATION_NA'],
        'longitude': coords[0],
        'latitude': coords[1]
    })

ds3_raw = pd.DataFrame(features)

# %% [markdown]
# To execute this spatial aggregation, the dataset is programmatically grouped by the `STATION_NA` identifier. We then calculate the geometric mean of all associated Latitude and Longitude coordinates to engineer a single, central "centroid" node for each transit hub.
#
# This mathematical condensation perfectly distills the 597 redundant exit points down into 186 unique and distinct spatial anchors. By engineering these singular nodes, we provide our downstream Haversine distance algorithm with exactly one unambiguous target per station. This is a critical structural safeguard; it guarantees that our regression model will process exactly one clean geographic vector for each transit hub, preventing the algorithm from being confused by overlapping or conflicting proximity metrics when evaluating a single HDB transaction.

# %%
# The dataset is grouped by "STATION_NA" and aggregated by the mean coordinates
ds3 = ds3_raw.groupby('STATION_NA').agg({
    'latitude': 'mean',
    'longitude': 'mean'
}).reset_index()

# The attribute name is cleaned for simplicity
ds3 = ds3.rename(columns={"STATION_NA": "Station_Name"})

# %% [markdown]
# The resulting DataFrame is presented below.

# %%
print(ds3)
# Out:
#                     Station_Name  latitude   longitude
# 0          ADMIRALTY MRT STATION  1.440407  103.800857
# 1           ALJUNIED MRT STATION  1.316363  103.882485
# 2         ANG MO KIO MRT STATION  1.369618  103.849676
# 3              BAKAU LRT STATION  1.388013  103.905464
# 4            BANGKIT LRT STATION  1.379853  103.772591
# ..                           ...       ...         ...
# 181  WOODLANDS SOUTH MRT STATION  1.426972  103.793958
# 182        WOODLEIGH MRT STATION  1.338987  103.870834
# 183          YEW TEE MRT STATION  1.397499  103.747267
# 184     YIO CHU KANG MRT STATION  1.381715  103.844809
# 185           YISHUN MRT STATION  1.429384  103.835049
#
# [186 rows x 3 columns]

# %% [markdown]
# ## **DS4: Educational Institutions**
# With the foundational directory from DS4 loaded, our objective is to isolate the specific spatial nodes representing Primary Schools across Singapore. We achieved this by applying a strict domain-specific filter to the mainlevel_code, followed by an aggressive dimensionality reduction protocol to strip away administrative metadata (such as telephone numbers and principal names).
#
# Isolating Primary Schools is not merely a data cleanliness exercise; it is an analytical necessity driven by localized real estate economics. The Ministry of Education enforces a strict "1km radius" priority system for Primary 1 registration, which exerts immense and highly localized pressure on surrounding housing valuations. By deliberately excluding Secondary and Tertiary institutions (which do not generate this same boundary-driven demand), we prevent signal dilution. This ensures our regression model isolates and learns the exact localized premium associated specifically with primary education.
#
# Furthermore, dropping the administrative metadata protects the algorithm from processing irrelevant noise. This distills the dataset down to its absolute structural prerequisites: the school's name, postal code, and textual address. While these retained variables are mathematically inert in their current string format, they act as the mandatory input seeds for our downstream OneMap API integration (Dataset 6), where they will be transformed into the mathematical coordinate space required for our proximity calculations.

# %%
ds4 = pd.read_csv("/content/Dataset 4.csv")

# Filter the dataset to retain only Primary Schools
ds4 = ds4[ds4['mainlevel_code'] == 'PRIMARY']

# Retain only relevant spatial and identification columns
ds4 = ds4[['school_name', 'postal_code', 'address']]

# %% [markdown]
# As a final preparation step for this dataset, we must address the structural formatting of the `postal_code` attribute. During the initial data ingestion, pandas natively infers these values as numeric integers. To rectify this, we execute a strict type coercion step, converting the integers back into explicit string objects and programmatically padding them to guarantee a uniform 6-digit architecture.
#
# While this appears to be a trivial cosmetic adjustment, it is actually a critical safeguard against catastrophic data loss. When Singaporean postal codes are processed as mathematical integers, any leading zeros are automatically truncated (for example, postal sector "048624" becomes "48624"). The downstream OneMap API endpoint operates on strict string matching; passing a truncated 5-digit payload will result in a failed HTTP response and a null coordinate return. By enforcing this explicit 6-digit string conversion, we guarantee perfect API payload conformity. This proactive formatting maximizes our spatial yield during the dynamic geocoding phase, directly preserving the volume of valid educational nodes available for our regression model to learn from.

# %%
# Convert postal code to a 6-digit string format
ds4['postal_code'] = ds4['postal_code'].astype(str).str.zfill(6)

# Reset index for clean formatting
ds4 = ds4.reset_index(drop=True)

# %% [markdown]
# The resulting DataFrame is presented below.

# %%
print(ds4)
# Out:
#                       school_name postal_code                        address
# 0        ADMIRALTY PRIMARY SCHOOL      738907         11 WOODLANDS CIRCLE
# 1    AHMAD IBRAHIM PRIMARY SCHOOL      768643         10 YISHUN STREET 11
# 2                  AI TONG SCHOOL      579646       100 Bright Hill Drive
# 3        ALEXANDRA PRIMARY SCHOOL      159016  2A Prince Charles Crescent
# 4     ANCHOR GREEN PRIMARY SCHOOL      544969         31 Anchorvale Drive
# ..                            ...         ...                            ...
# 174          YUHUA PRIMARY SCHOOL      609558   158 JURONG EAST STREET 24
# 175          YUMIN PRIMARY SCHOOL      529393        3 TAMPINES STREET 21
# 176        ZHANGDE PRIMARY SCHOOL      169485            51 Jalan Membina
# 177       ZHENGHUA PRIMARY SCHOOL      679002                9 Fajar Road
# 178       ZHONGHUA PRIMARY SCHOOL      556095       12 SERANGOON AVENUE 4
#
# [179 rows x 3 columns]

# %% [markdown]
# ## **DS5: Macroeconomic Trends (CPI)**
# With the raw CPI matrix loaded, our objective is to extract a singular economic baseline to normalize our historical transaction prices. To achieve this, we apply a strict row-level filter to isolate the overarching "All Items" macro-index, followed by the deliberate removal of all administrative footnotes appended to the bottom of the dataset.
#
# Isolating the "All Items" index functions as an aggressive dimensionality reduction step. The raw dataset contains hundreds of specific micro-indices (such as inflation for apparel or public transport). Retaining these granular sub-categories would introduce severe algorithmic noise, potentially forcing the regression model to calculate spurious correlations between housing valuation and irrelevant consumer goods. By extracting only the macroeconomic baseline, we establish a clean mathematical anchor to adjust our target variable, allowing the model to strictly differentiate between genuine real estate appreciation and baseline currency inflation.
#
# Furthermore, dropping the administrative footnotes is not merely a cosmetic cleanup; it is a structural prerequisite. In raw datasets, appended text rows disrupt the rectangular matrix structure and frequently cause fatal type-coercion errors (forcing Python to interpret a column of decimal numbers as a column of text strings). By purging these non-numeric rows, we guarantee the absolute structural integrity and continuous data typing required before we execute the complex matrix transposition (melting) in our next step.

# %%
# The correct sheet is targeted and metadata headers are bypassed
ds5 = pd.read_excel("/content/Dataset 5.xlsx", sheet_name='T6', skiprows=10)

# Rows lacking actual CPI data (footnotes) are dropped
ds5 = ds5.dropna(subset=['2025 Dec'])

# The dataset is filtered to retain only the general "All Items" index
ds5['Data Series'] = ds5['Data Series'].str.strip()
ds5 = ds5[ds5['Data Series'] == 'All Items']

# %% [markdown]
# With the macroeconomic baseline isolated, our next objective is to radically restructure the dataframe. Because the native data is published as a "wide" matrix (where hundreds of historical months act as individual column headers), we execute a `pd.melt()` operation to transpose these scattered temporal dimensions into a continuous time-series format.
#
# This structural transformation is a strict relational prerequisite. A wide matrix is fundamentally incompatible with the transaction logs in DS1. By melting the dataframe, we consolidate the timeline into a singular Date feature alongside its corresponding CPI value. This engineers the exact composite joining keys required to map historical inflation rates directly to individual housing transactions during our downstream merge.
#
# Furthermore, we must address critical data type corruption. The native dataset encodes missing historical indices as the text string 'na'. If left untreated during the transposition, these textual artifacts force the entire CPI column to be classified as a categorical object. Since regression algorithms cannot compute mathematical adjustments on text, we systematically drop these anomalies and explicitly coerce the column into continuous numeric floats. This protocol guarantees the absolute mathematical compatibility of our macroeconomic data before we apply the inflation adjustment formula.

# %%
# The dataset is melted from a wide format to a long format
ds5 = ds5.melt(id_vars=["Data Series"], var_name="Date", value_name="CPI")

# Missing historical values ('na') are dropped and CPI is converted to numeric
ds5 = ds5[ds5['CPI'] != 'na']
ds5['CPI'] = pd.to_numeric(ds5['CPI'])

# %% [markdown]
# Following the matrix transposition, the newly formed Date attribute (originally formatted as a categorical "YYYY-MM" string) is parsed to extract the explicit Year and Month components. These isolated elements are then stored as independent integer variables.
#
# While this string manipulation appears straightforward, it serves as the final, critical relational prerequisite before our data integration phase. By extracting these discrete temporal integers, we deliberately engineer the exact composite joining keys necessary to execute a deterministic merge with our core transaction logs (DS1). Ensuring both datasets share an identical temporal architecture is non-negotiable; without these matching integer keys, the algorithm would be entirely unable to accurately map the correct historical inflation rate to its corresponding housing transaction, which would permanently sever the macroeconomic context from our predictive model.

# %%
ds5["Date"] = pd.to_datetime(ds5["Date"], format="%Y %b", errors="coerce")
ds5 = ds5.dropna(subset=["Date"])

ds5["Year"] = ds5["Date"].dt.year.astype(int)
ds5["Month"] = ds5["Date"].dt.month.astype(int)

# %% [markdown]
# As the final preparation step for our macroeconomic baseline, the dataframe is strictly sorted by the newly engineered Year and Month integers. Following this chronological alignment, all remaining redundant columns are systematically dropped.
#
# Sorting the data is not merely an organizational preference; it is a fundamental mathematical requirement for time-series integrity. By enforcing a strict chronological hierarchy, we ensure that the historical progression of inflation is explicitly preserved. In predictive modeling, failing to strictly sequence historical data can lead to temporal data leakage, a fatal error where the algorithm accidentally accesses future trends to predict past outcomes.
#
# Furthermore, dropping redundant attributes elevates our structural optimization. Retaining deprecated columns (such as the original, unparsed date strings) inflates the dataset's dimensionality without contributing any new predictive variance. By explicitly purging these duplicate features, we protect the algorithm from processing meaningless mathematical noise and finalize a clean, highly optimized macroeconomic matrix ready for immediate integration with our transaction logs.

# %%
# The dataset is sorted by "Year" and "Month" and redundant columns are dropped
ds5 = ds5.drop(columns=["Data Series", "Date"]).sort_values(["Year", "Month"]).reset_index(drop=True)

# %% [markdown]
# The resulting DataFrame is presented as follows.

# %%
print(ds5)
# Out:
#          CPI  Year  Month
# 0     21.071  1961      1
# 1     21.094  1961      2
# 2     21.112  1961      3
# 3     20.770  1961      4
# 4     20.655  1961      5
# ..       ...   ...    ...
# 775  100.963  2025      8
# 776  101.320  2025      9
# 777  101.330  2025     10
# 778  101.579  2025     11
# 779  101.854  2025     12
#
# [780 rows x 3 columns]

# %% [markdown]
# ## **DS6: OneMap API Geocoding**
# With the programmatic infrastructure for the OneMap API (DS6) established, our objective is to construct fully geocoded, mathematically viable DataFrames for our spatial features.
#
# As previously established during data profiling, our foundational structural datasets (specifically HDB Blocks and Educational Institutions) natively suffer from complete spatial blindness. They possess categorical textual addresses but entirely lack the mathematical coordinates required for proximity calculations. To resolve this structural deficit, we deploy a dynamic geocoding pipeline, utilizing our custom API function to iteratively query the live endpoint.
#
# Using our prepared Primary Schools dataset as the execution baseline, we programmatically pass each sanitized 6-digit postal code into the API payload. This process acts as a mathematical translator, converting human-readable addresses into precise, continuous numerical vectors (Latitude and Longitude). This iterative extraction is not merely a data completion exercise; it is an absolute algorithmic prerequisite. Generating these exact spatial anchors is the only methodology that empowers our downstream Haversine algorithm to compute the physical proximity metrics necessary for the regression model to evaluate neighborhood desirability.

# %%
# Import the progress bar library at the top
from tqdm import tqdm
import time

latitudes = []
longitudes = []

# Wrap your list in tqdm() to see a live loading bar!
for postal in tqdm(ds4['postal_code'], desc="Geocoding Schools"):
    coords = get_coordinates(postal)

    if coords:
        latitudes.append(coords['latitude'])
        longitudes.append(coords['longitude'])
    else:
        latitudes.append(None)
        longitudes.append(None)

    time.sleep(0.25)

ds4['latitude'] = latitudes
ds4['longitude'] = longitudes
# Out:
# Geocoding Schools: 100%|██████████| 179/179 [04:30<00:00,  1.51s/it]

# %% [markdown]
# Following the iterative API extraction, we must systematically address spatial nullification. The OneMap API inherently queries the contemporary topography of Singapore. Consequently, applying historical transaction data to this live endpoint inevitably yields a fraction of failed responses (null coordinates) for buildings or institutions that have since been demolished, relocated, or structurally reclassified.
#
# To prevent the downstream regression algorithms from encountering fatal errors when processing these missing coordinates, we execute a strict deletion of all unresolved rows. While this deliberate omission introduces a mathematically unavoidable degree of survivorship bias into our time-series dataset, it is an absolute structural necessity. Purging these failed queries guarantees unbroken spatial integrity across our modeling architecture, ensuring the algorithm trains exclusively on validated, high-confidence geographic vectors.

# %%
# Rows that failed to geocode correctly are dropped
ds4 = ds4.dropna(subset=['latitude', 'longitude']).reset_index(drop=True)

# Note: The exact same iterative geocoding logic is simultaneously applied
# to DS2 (HDB blocks) by passing the concatenated string of 'blk_no' and 'street'
# into the API to extract the specific coordinates of every transacted block.

# %% [markdown]
# The resulting, fully-geocoded DataFrame is presented as follows.

# %%
print(ds4)
# Out:
#                       school_name postal_code                        address  \
# 0        ADMIRALTY PRIMARY SCHOOL      738907         11 WOODLANDS CIRCLE
# 1    AHMAD IBRAHIM PRIMARY SCHOOL      768643         10 YISHUN STREET 11
# 2                  AI TONG SCHOOL      579646       100 Bright Hill Drive
# 3        ALEXANDRA PRIMARY SCHOOL      159016  2A Prince Charles Crescent
# 4     ANCHOR GREEN PRIMARY SCHOOL      544969         31 Anchorvale Drive
# ..                            ...         ...                            ...
# 174          YUHUA PRIMARY SCHOOL      609558   158 JURONG EAST STREET 24
# 175          YUMIN PRIMARY SCHOOL      529393        3 TAMPINES STREET 21
# 176        ZHANGDE PRIMARY SCHOOL      169485            51 Jalan Membina
# 177       ZHENGHUA PRIMARY SCHOOL      679002                9 Fajar Road
# 178       ZHONGHUA PRIMARY SCHOOL      556095       12 SERANGOON AVENUE 4
#
#      latitude   longitude
# 0    1.442635  103.800040
# ...

# %%
from tqdm import tqdm
import time
import pandas as pd

# 1. Extract unique HDB addresses from DS1
unique_addresses = ds1[['block', 'street_name']].drop_duplicates().copy()

# 2. Combine block and street to create a search query for the API
unique_addresses['search_address'] = unique_addresses['block'].astype(str) + " " + unique_addresses['street_name']

latitudes = []
longitudes = []

# 3. Iterate and fetch coordinates
print(f"Geocoding {len(unique_addresses)} unique HDB blocks. This will take a few minutes...")
for addr in tqdm(unique_addresses['search_address'], desc="Geocoding HDBs"):
    coords = get_coordinates(addr) # Using your custom OneMap API function

    if coords:
        latitudes.append(coords['latitude'])
        longitudes.append(coords['longitude'])
    else:
        latitudes.append(None)
        longitudes.append(None)

    time.sleep(0.1) # Respecting rate limits

unique_addresses['latitude'] = latitudes
unique_addresses['longitude'] = longitudes

# 4. Drop failed geocodes
unique_addresses = unique_addresses.dropna(subset=['latitude', 'longitude'])
# Out:
# Geocoding 9681 unique HDB blocks. This will take a few minutes...
# Geocoding HDBs: 100%|██████████| 9681/9681 [3:13:29<00:00,  1.20s/it]

# %% [markdown]
# # **Data Consolidation**
# Following the rigorous pre-processing, dimensionality reduction, and structural harmonization of our independent data sources, the final prerequisite of our engineering pipeline is the construction of a singular Master DataFrame.
#
# This consolidated architectural matrix acts as the mathematical foundation for our entire project. By executing a series of deterministic relational merges, we transition our isolated structural, geospatial, and macroeconomic variables into a cohesive analytical substrate. This unified schema is a strict algorithmic necessity; it aligns the diverse predictive vectors—ranging from block-level amenities and localized school proximity to macro-level inflation—into a single continuous mathematical space. Ultimately, this master matrix serves as the mandatory baseline for both our multi-dimensional Exploratory Data Analysis (EDA) and the downstream training of our predictive regression architecture.

# %% [markdown]
# ## **Phase 1: Relational Merging**
# The initial phase of our master consolidation executes a deterministic relational merge between our core transaction logs (DS1) and the macroeconomic baseline (DS5). By utilizing the explicit chronological axes (Year and Month) as composite joining keys, we structurally synchronize hundreds of thousands of micro-level housing transactions with their exact corresponding macroeconomic climate. This temporal alignment is a strict algorithmic prerequisite; it establishes the mathematical foundation necessary to eventually compute an inflation-adjusted target variable, ensuring our model learns genuine property value rather than currency fluctuation.
#
# Immediately following the temporal integration, we project the intrinsic architectural attributes (DS2) onto our newly synchronized timeline. This is achieved via a secondary relational merge, utilizing the physical address components (block and street_name) as the joining keys. This operation acts as a structural enrichment layer. It effectively overlays the physical constraints of the housing market (such as maximum floor levels and block-specific commercial zoning) directly onto the financial data. This empowers the downstream regression architecture to evaluate physical depreciation and vertical space premiums alongside broader market trends.

# %%
# Merging HDB Transactions (DS1) with Macroeconomic CPI (DS5) on time axes
master_df = pd.merge(ds1, ds5, on=["Year", "Month"], how="left")

# Merging the resulting DataFrame with intrinsic Property Information (DS2) on location axes
# Note: DS1 uses 'block' and 'street_name', while DS2 uses 'blk_no' and 'street'
master_df = pd.merge(master_df, ds2, left_on=["block", "street_name"], right_on=["blk_no", "street"], how="left")

# Dropping the redundant linking columns from DS2 to optimise memory
master_df = master_df.drop(columns=["blk_no", "street"])

# %% [markdown]
# ## **Phase 2: Financial Standardisation (Inflation Adjustment)**
# With our relational matrices successfully merged, we must address the most severe temporal distortion present within our longitudinal dataset. Because our transaction timeline spans a continuous decade (2017 to 2026), the baseline purchasing power of the currency has undergone significant macroeconomic fluctuation.
#
# Preparation Rationale & Modeling Suitability:
# If we were to train our regression architecture natively on the raw nominal transaction prices, the algorithm would inevitably conflate baseline currency devaluation with genuine real estate appreciation. This would severely corrupt the model's predictive weights, causing it to falsely attribute price increases to structural or spatial features when the variance was actually driven by national inflation.
#
# To systematically eliminate this macroeconomic noise, we engineer a standardized target variable: adjusted_resale_price. By applying the merged CPI index to execute a deterministic mathematical transformation, we anchor all historical transactions to a singular, normalized economic baseline. This critical engineering step forces the predictive model to ignore overarching currency inflation and optimize its gradient strictly around the intrinsic valuation and true market desirability of the properties.

# %%
# The real adjusted price is calculated by normalising the nominal resale price against the CPI.
# Our CPI dataset uses 2024 as the base year (Base Index = 100).
master_df["adjusted_resale_price"] = master_df["resale_price"] / (master_df["CPI"] / 100)

# We drop the raw CPI column as it has served its purpose
master_df = master_df.drop(columns=["CPI"])

# %% [markdown]
# ## **Phase 3: Spatial Integration (Calculating Proximity)**
# With our structural and educational datasets successfully mapped into a continuous coordinate space, our subsequent objective is to engineer quantitative proximity features. To achieve this, we deploy a vectorized implementation of the Haversine formula across our spatial matrices.
#
# It is analytically crucial to distinguish that the Haversine algorithm calculates the great-circle distance (the absolute shortest trajectory between two points on a spherical plane) rather than routed pedestrian walking distance. While calculating literal street-level routing would provide hyper-accurate pedestrian metrics, querying a routing API across hundreds of thousands of historical transactions is computationally prohibitive and exposes the pipeline to severe latency.
#
# To overcome this bottleneck, we execute a vectorized Haversine calculation. By utilizing array-level mathematical operations rather than iterative loops, we instantly synthesize highly efficient, continuous numerical features that represent linear proximity. These calculated spatial vectors act as robust mathematical proxies for urban accessibility. They provide the regression algorithm with the exact quantitative gradients required to evaluate locational desirability without paralyzing our computational infrastructure.

# %%
import numpy as np
from tqdm import tqdm

def haversine_vectorized(lat1, lon1, lat2, lon2):
    """
    Calculates the great-circle distance between two spatial points in kilometres.
    """
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])

    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    r = 6371
    return c * r

def get_nearest_distance(row, facilities_df):
    distances = haversine_vectorized(row['latitude'], row['longitude'], facilities_df['latitude'], facilities_df['longitude'])
    return distances.min()

# This enables the progress_apply feature in pandas
tqdm.pandas(desc="Calculating Distances")

# 1. Merge the newly geocoded coordinates into the master dataset
master_df = pd.merge(master_df, unique_addresses[['block', 'street_name', 'latitude', 'longitude']],
                     on=['block', 'street_name'], how='inner')

# 2. Use progress_apply instead of apply to see a loading bar!
print("Calculating MRT Distances...")
master_df['dist_to_nearest_mrt'] = master_df.progress_apply(lambda row: get_nearest_distance(row, ds3), axis=1)

print("Calculating School Distances...")
master_df['dist_to_nearest_school'] = master_df.progress_apply(lambda row: get_nearest_distance(row, ds4), axis=1)

print("Spatial Integration Complete!")
# Out:
# Calculating MRT Distances...
# Calculating Distances: 100%|██████████| 224220/224220 [04:24<00:00, 847.29it/s]
# Calculating School Distances...
# Calculating Distances: 100%|██████████| 224220/224220 [04:23<00:00, 851.62it/s]
# Spatial Integration Complete!

# %% [markdown]
# Finally, we drop any residual missing values created during the merging process and inspect our finalised Master DataFrame.

# %%
master_df = master_df.dropna().reset_index(drop=True)
print(master_df.head())
# Out:
#          town flat_type block        street_name storey_range  floor_area_sqm  \
# 0  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12            44.0
# 1  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03            67.0
# 2  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03            67.0
# 3  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06            68.0
# 4  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03            67.0
#
#        flat_model  lease_commence_date  resale_price  Year  ...  \
# 0        Improved                 1979      232000.0  2017  ...
# 1  New Generation                 1978      250000.0  2017  ...
# 2  New Generation                 1980      262000.0  2017  ...
# 3  New Generation                 1980      265000.0  2017  ...
# 4  New Generation                 1980      265000.0  2017  ...
#
#    miscellaneous  multistorey_carpark  precinct_pavilion  bldg_contract_town  \
# ...

# %% [markdown]
# # **Exploratory Data Analysis & Regression Modelling**
# With the master relational matrix successfully consolidated, we transition from data engineering to formal statistical investigation. Our research design is deliberately bifurcated: we first utilize cross-sectional analysis to understand the "why" behind property valuation, and then apply time-series forecasting to understand the "where" of market trajectories.
#
# ## **Phase 1: Feature Engineering (Residual Variable Synthesis)**
# The first phase focuses on converting latent information into explicit mathematical signals. This involves the synthesis of variables such as the numeric `remaining_lease` and the `storey_midpoint`. These transformations are critical to ensuring the regression gradient can accurately map the linear decay and elevation premiums inherent in the Singaporean housing market.
#
# ## **Phase 2: Exploratory Data Analysis (Distributional Integrity)**
# In this phase, we execute a multi-dimensional audit of our feature space. By visualizing the central tendencies and variances of our key attributes, we can detect any underlying distributional skew. This is a mathematical prerequisite for regression modeling, as it allows us to identify if specific variables require log-transformations to meet the assumption of normality.
#
# ## **Phase 3: Correlation Analysis (Multivariate Signal Mapping)**
# Before model initialization, we utilize a Pearson correlation matrix to isolate the strongest linear drivers of the adjusted_resale_price. This phase is analytically vital for identifying potential multicollinearity between features such as the relationship between flat size and room count—ensuring we do not introduce redundant variables that could distort our model's coefficients.
#
# ## **Phase 4: OLS Multiple Linear Regression (Cross-Sectional Attribution)**
# We deploy an Ordinary Least Squares (OLS) model to function as our primary explanatory engine. Unlike "black-box" machine learning models, OLS provides transparent coefficients that allow us to precisely quantify the monetary impact of every meter of space, every kilometer of transit proximity, and every year of lease decay. This phase directly addresses the "drivers" of current market pricing.
#
# ## **Phase 5: Time-Series Analysis (SARIMAX Forecasting)**
# While OLS explains price drivers, the SARIMAX model accounts for the temporal momentum of the market. By incorporating Seasonal Autoregressive Integrated Moving Average components with eXogenous variables (like our engineered CPI), we can forecast future price trends while accounting for the periodic fluctuations and macroeconomic shifts inherent in the housing timeline.
#
# ## **Phase 6: Hypothesis Validation (Empirical Conclusion)**
# The final phase serves as the rigorous culmination of our research. We revert to our initial three hypotheses, utilizing the mathematical outputs from our models to either confirm or refute our original assumptions. This provides a formal, evidence-based conclusion to our investigation, grounded in absolute statistical significance.

# %% [markdown]
# ## **Phase 1: Feature Engineering**
# To finalize the preparation of our analytical substrate, we address the remaining categorical variables that represent ordinal hierarchies, specifically the `storey_range`. In its native format, this attribute is stored as a textual range (for example, "10 TO 12"), which renders it mathematically inert for regression analysis.
#
# Retaining these text-based bands would force the regression algorithm to treat distinct vertical levels as isolated categorical bins. This would fundamentally obscure the natural linear relationship between building height and property valuation. To resolve this, we execute a continuous feature synthesis by calculating the numeric midpoint of each range.
#
# This transformation facilitates a more granular and accurate calculation of the vertical space premium. By interpolating these textual bands into a continuous numerical gradient, we empower the model to identify the exact price elasticity associated with each additional floor of elevation. This ensures the algorithm can mathematically capture the incremental value that height provides to a property's market desirability without the statistical loss associated with categorical encoding.

# %%
def get_storey_midpoint(storey_str):
    """Extract numeric midpoint from storey_range string (e.g., '04 TO 06' -> 5.0)."""
    try:
        parts = storey_str.split(' TO ')
        return (int(parts[0]) + int(parts[1])) / 2.0
    except:
        return np.nan

master_df['storey_midpoint'] = master_df['storey_range'].apply(get_storey_midpoint)

# --- 1b. Remaining Lease ---
master_df['remaining_lease'] = 99 - (master_df['Year'] - master_df['lease_commence_date'])

# --- 1c. Clean up any NaNs introduced ---
master_df = master_df.dropna(subset=['storey_midpoint', 'remaining_lease']).reset_index(drop=True)

print("Step 1 Complete: Feature Engineering (Unchanged)")
print(f"Master DataFrame shape: {master_df.shape}")
print(f"\nDerived features sample:")
print(master_df[['storey_range', 'storey_midpoint', 'lease_commence_date', 'Year', 'remaining_lease']].head())
# Out:
# Step 1 Complete: Feature Engineering (Unchanged)
# Master DataFrame shape: (222077, 28)
#
# Derived features sample:
#   storey_range  storey_midpoint  lease_commence_date  Year  remaining_lease
# 0     10 TO 12             11.0                 1979  2017               61
# 1     01 TO 03              2.0                 1978  2017               60
# 2     01 TO 03              2.0                 1980  2017               62
# 3     04 TO 06              5.0                 1980  2017               62
# 4     01 TO 03              2.0                 1980  2017               62

# %% [markdown]
# ## **Phase 2: Exploratory Data Analysis**
# ### **2.1 Descriptive Statistics**
# Before conducting multivariate analysis, we execute a rigorous audit of the basic statistical properties across our primary numeric feature space. This involves quantifying the central tendency, dispersion, and mathematical scale of each variable.
#
# This descriptive phase is a non-negotiable diagnostic prerequisite. By examining the distribution of variables such as floor_area_sqm and our target adjusted_resale_price, we can identify significant skewness or extreme outliers that could mathematically destabilize an OLS regression model. Identifying the scale of these features ensures that variables with larger numeric ranges do not disproportionately dominate the model's coefficients during the training phase. This audit provides the baseline clarity needed to determine if further normalization or log-transformations are required to satisfy the fundamental algorithmic assumptions of homoscedasticity and normality.

# %%
desc_cols = ['adjusted_resale_price', 'floor_area_sqm', 'storey_midpoint',
             'remaining_lease', 'dist_to_nearest_mrt', 'dist_to_nearest_school']

print(master_df[desc_cols].describe().round(2))
# Out:
#        adjusted_resale_price  floor_area_sqm  storey_midpoint  \
# count              222077.00       222077.00        222077.00
# mean               568951.84           96.77             8.77
# std                189989.92           24.02             5.94
# min                151244.74           31.00             2.00
# 25%                429488.91           81.00             5.00
# 50%                537885.87           93.00             8.00
# 75%                671009.30          112.00            11.00
# max               1644091.18          366.70            50.00
#
#        remaining_lease  dist_to_nearest_mrt  dist_to_nearest_school
# count        222077.00            222077.00               222077.00
# mean             74.22                 0.61                    0.42
# std              14.20                 0.37                    0.26
# min              40.00                 0.03                    0.04
# ...

# %% [markdown]
# ## **Target Variable Analysis: Adjusted Resale Price**
# The `adjusted_resale_price` exhibits a clear right-skewed distribution. With a mean of approximately $568,951 and a median (50%) of $537,885, the mean is pulled upward by high-value transactions. This is further evidenced by the maximum value of $1,644,091, representing the "million-dollar HDB" outliers often found in prime districts or high-floor premium blocks. For your OLS model, this skewness suggests that a log-transformation of the target variable might be necessary to stabilize the variance and satisfy the assumption of normality in the residuals.
#
# ## **Structural Features: Floor Area and Vertical Elevation**
# The physical attributes of the flats show high variance but predictable clustering:
#
# * **Floor Area**: The mean of 96.77 sqm perfectly aligns with the standard size of a modern 4-room HDB flat. However, the maximum value of 366.70 sqm is nearly four times the average, likely representing rare "Jumbo" flats or multi-generational units. These extreme outliers in floor area will exert high leverage on your regression coefficients.
#
# * **Storey Midpoint**: The median height is the 8th floor, which is standard for older Singaporean precincts. The maximum height of 50 represents the vertical expansion of public housing (such as the Pinnacle@Duxton). The standard deviation of 5.94 suggests that while most flats are low-to-mid rise, there is enough vertical dispersion to accurately measure the height-based price premium.
#
# ## **Temporal Decay: Remaining Lease Years**
# * The remaining_lease_years attribute ranges from 40 to 98 years, with a mean of 74.22.
#
# * The 25th percentile sits at 62 years, indicating that a significant portion of your dataset involves older flats nearing the "critical 60-year mark" where CPF usage and bank loan restrictions begin to impact liquidity.
#
# This dispersion is ideal for our model as it provides enough historical depth to quantify how the rate of depreciation accelerates as the lease approaches its terminal 99-year limit.
#
# ## **Spatial Proximity: MRT and School Accessibility**
# The proximity metrics reveal the dense, transit-oriented nature of Singapore’s urban planning:
#
# * **MRT Proximity**: The average distance to a station is just 0.61 km. Notably, 75% of all transactions are within 0.81 km of a train station, confirming that "walking distance" is a core characteristic of the vast majority of HDB blocks.
#
# * **School Proximity**: Accessibility to primary education is even tighter, with a mean of 0.42 km. This extreme proximity (with a maximum of only 3.3 km) suggests that the "school premium" will be a highly sensitive variable in your model, as nearly every flat is located within the critical 1 km or 2 km radius.

# %% [markdown]
# ### **2.2 Distribution of Adjusted Resale Price**
#
# The distribution of the target variable serves as a critical diagnostic for selecting the optimal regression architecture. In this phase, we execute a rigorous assessment of the skewness within the `adjusted_resale_price` feature to determine if the data adheres to the fundamental assumptions of linear modeling.
#
# Property valuation data is characteristically prone to right-skewed distributions. This happens because a relatively small volume of high-end transactions creates a "long tail" that pulls the mean significantly higher than the median. If we were to apply a standard Ordinary Least Squares (OLS) model to this raw, non-normal distribution, we would likely encounter heteroscedasticity. This is a condition where the variance of our model residuals is not constant, leading to inefficient estimates and skewed predictions for premium properties.
#
# To rectify this, we apply a logarithmic transformation to the target variable. By compressing the extreme values in the right tail, we normalize the distribution into a more symmetrical bell curve. This transformation is not merely a mathematical cleanup; it shifts the model objective from predicting absolute dollar differences to predicting percentage-based variations. This is a far more robust approach for real estate analysis, as it accounts for the fact that a fixed price increase represents a different proportional value depending on the baseline price of the flat.

# %%
fig, ax = plt.subplots(figsize=(12, 5))
sns.histplot(master_df['adjusted_resale_price'], bins=60, kde=True, color='steelblue', ax=ax)
ax.axvline(master_df['adjusted_resale_price'].mean(), color='red', linestyle='--',
           label=f"Mean: ${master_df['adjusted_resale_price'].mean():,.0f}")
ax.axvline(master_df['adjusted_resale_price'].median(), color='green', linestyle='--',
           label=f"Median: ${master_df['adjusted_resale_price'].median():,.0f}")
ax.set_title('Distribution of Inflation-Adjusted Resale Price', fontsize=14, fontweight='bold')
ax.set_xlabel('Adjusted Resale Price (SGD)')
ax.legend()
plt.tight_layout()
plt.show()

print(f"Skewness: {skew(master_df['adjusted_resale_price'].dropna()):.4f}")
# Out:
# Skewness: 0.9363

# %% [markdown]
# The visualization of the **adjusted_resale_price** provides a definitive diagnostic of the target variable's distribution. With a calculated skewness of **0.9363**, the dataset exhibits a moderate positive skew, which has significant implications for our downstream regression architecture.
#
# ---
# The histogram confirms a classic real estate valuation pattern where the majority of transactions cluster around the \$400,000 to \$600,000 range, while a persistent long tail extends toward the \$1.6 million mark.
#
# **Diagnostic Observations:**
# * **Mean vs. Median:** The visible gap between the median (\$537,886) and the mean (\$568,952) is a clear indicator that high-value outliers are exerting an upward pull on the average.
# * **Skewness Coefficient:** While a coefficient of 0.9363 is not considered extreme, it is sufficient to threaten the validity of an Ordinary Least Squares (OLS) model.
# * **Heteroscedasticity Risk:** Standard linear regression assumes that the residuals are normally distributed and exhibit constant variance. In a skewed dataset like this, the model's error variance often increases in proportion to the price. This means the algorithm would likely be accurate for standard flats but could become inconsistent when predicting the valuation of premium, high-floor, or central area units.
#
# ### **The Logarithmic Solution**
#
# To mitigate this risk and ensure the algorithm treats price changes as proportional percentages rather than raw dollar increments, we apply a natural log transformation:
#
# $$Target_{trans} = \ln(adjusted\_resale\_price)$$
#
# This mathematical adjustment will compress the right tail and pull the distribution closer to a symmetrical bell curve. This ensures that our regression gradients are calculated against a stable, normalized target, leading to more robust coefficients and higher predictive reliability across all price segments of the HDB market.

# %% [markdown]
# ### **2.3 Monthly Median Resale Price Trend**
#
# To quantify the overarching market momentum, we plot the monthly median resale price across our ten-year longitudinal dataset. We visualize both the nominal (raw) transaction prices and our engineered `adjusted_resale_price` to expose the significant impact of Consumer Price Index (CPI) normalization.
#
# Visualizing the divergence between nominal and inflation-adjusted prices is a vital diagnostic for establishing signal integrity. In any long-term financial dataset, nominal prices are inherently corrupted by monetary noise. The gap between the two trend lines represents the cumulative effect of inflation: the portion of the price increase that is driven by the decreasing purchasing power of the currency rather than the actual appreciation of the real estate asset.
#
# **Strategic Implications for Regression Modeling:**
# * **Isolating Asset Appreciation:** By focusing on the inflation-adjusted line, we can observe the "real" growth cycles of the HDB market. This ensures that our subsequent regression analysis identifies the structural and locational drivers of value rather than simply reflecting the passage of time.
# * **Detecting Macroeconomic Shifts:** Periods where the gap widens significantly indicate high-inflation environments where nominal price spikes may be deceptive.
# * **Target Variable Validation:** This plot serves as the final validation for our `adjusted_resale_price` feature. It ensures that the normalization has successfully stabilized the temporal axis, providing a clean and uncorrupted target for our machine learning algorithms to optimize against.

# %%
master_df['date'] = pd.to_datetime(master_df['Year'].astype(str) + '-' + master_df['Month'].astype(str), format='%Y-%m')
monthly = master_df.groupby('date').agg(
    median_adjusted=('adjusted_resale_price', 'median'),
    median_nominal=('resale_price', 'median')
).reset_index()

fig, ax = plt.subplots(figsize=(14, 6))
ax.plot(monthly['date'], monthly['median_adjusted'], color='steelblue',
        linewidth=2, label='Inflation-Adjusted Price')
ax.plot(monthly['date'], monthly['median_nominal'], color='coral',
        linewidth=2, linestyle='--', alpha=0.7, label='Nominal Price')
ax.set_title('Monthly Median HDB Resale Price (2017-2025)', fontsize=14, fontweight='bold')
ax.set_xlabel('Date')
ax.set_ylabel('Median Price (SGD)')
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()

print(f"Price at start: SGD {monthly['median_adjusted'].iloc[0]:,.0f}")
print(f"Price at end:   SGD {monthly['median_adjusted'].iloc[-1]:,.0f}")
# Out:
# Price at start: SGD 475,900
# Price at end:   SGD 623,441

# %% [markdown]
# The longitudinal visualization of monthly median resale prices reveals the stark contrast between nominal market movement and inflation-adjusted value. By anchoring historical transactions to a contemporary Consumer Price Index (CPI) baseline, we effectively translate historical dollar values into their modern equivalent.
#
# ### **Empirical Observations and Market Dynamics**
#
# This visualization provides three critical insights into the Singaporean HDB landscape between 2017 and 2025:
#
# * **Initial Valuation Offset:** At the commencement of our observation period in early 2017, the inflation-adjusted median price starts at **SGD 475,900**, while the nominal price sits significantly lower at approximately **SGD 410,000**. This gap represents the scale of currency devaluation over the decade. It illustrates that a property purchased in 2017 carried a higher relative economic cost in today's terms than the raw price indicates.
# * **The 2020 Structural Pivot:** Both metrics exhibit a definitive inflection point following the year 2020. This indicates a period of genuine asset appreciation that significantly outpaced baseline inflation. This sharp upward trajectory is likely a reflection of pandemic-related market shifts, such as construction delays and an increased premium on residential living space.
# * **Convergence and Present-Value Alignment:** As the timeline progresses into late 2025, the nominal and adjusted lines converge at a terminal median valuation of **SGD 623,441**. This convergence confirms that our normalization logic is correctly anchored to the present era. It provides a stabilized baseline for our subsequent regression models to evaluate price movements with chronological clarity.
#
# ### **Modeling Suitability**
#
# This trend analysis confirms that using raw nominal prices would have introduced significant temporal bias into our machine learning pipeline. By utilizing the `adjusted_resale_price` instead, we ensure that our regression algorithm is optimized to detect the intrinsic drivers of property value, such as location and floor area

# %% [markdown]
# ### **2.4 Average Price by Flat Type**
# Following our temporal analysis, we evaluate the impact of structural classification on property valuation. By comparing the mean `adjusted_resale_price` across different flat types, we can empirically confirm the relationship between unit size and market pricing.
#
# ### **Analytical Rationale and Modeling Suitability**
#
# In the Singaporean housing market, flat type acts as a primary proxy for both square footage and household utility. We expect a definitive positive correlation where larger configurations (such as 5-Room and Executive units) command significantly higher price points than smaller 2-Room or 3-Room counterparts.
#
# **Modeling Implications:**
# * **Variance Detection:** This analysis allows us to identify the "price jumps" between different categories. If the price difference between a 4-Room and 5-Room flat is disproportionately large compared to the difference in their average floor area, it suggests that buyers are paying a premium for the "type" classification itself, rather than just the raw square footage.
# * **Categorical Encoding Strategy:** Because flat types follow a logical progression (1 < 2 < 3 < 4 < 5 < Executive), they possess an inherent ordinal nature. However, for our regression architecture, we must decide whether to treat them as an ordinal sequence or as distinct nominal categories via one-hot encoding. This visualization helps determine if the price increases are linear enough to support an ordinal approach or if distinct category-specific coefficients are required to capture non-linear premiums.
#
#
#
# ### **Expected Empirical Trends**
# We anticipate a staircase-like distribution where the mean valuation increases monotonically with the complexity of the flat type. Any deviations from this trend (such as a 4-Room flat averaging higher than a 5-Room flat in certain districts) would signal the presence of powerful confounding variables like location or remaining lease years, which our final regression model will be required to untangle.

# %%
order = ['1 ROOM', '2 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', 'EXECUTIVE', 'MULTI-GENERATION']
avg_by_type = master_df.groupby('flat_type')['adjusted_resale_price'].mean().reindex(order)

fig, ax = plt.subplots(figsize=(10, 5))
bars = ax.bar(avg_by_type.index, avg_by_type.values, color=sns.color_palette('Set2', len(avg_by_type)))
ax.set_title('Mean Adjusted Resale Price by Flat Type', fontsize=14, fontweight='bold')
ax.set_ylabel('Mean Adjusted Price (SGD)')
ax.set_xlabel('Flat Type')
for bar, val in zip(bars, avg_by_type.values):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 5000,
            f'SGD {val:,.0f}', ha='center', fontsize=9, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# The cross-sectional analysis of mean `adjusted_resale_price` across flat types provides an empirical validation of the structural hierarchy within the Singaporean public housing market. The visualization confirms a definitive monotonic progression where unit complexity and square footage translate directly into higher market valuations.
#
# ### **Empirical Observations and Structural Insights**
# * **The Entry-Level Gradient:** The transition from **1 ROOM (SGD 231,562)** to **2 ROOM (SGD 317,524)** and **3 ROOM (SGD 402,278)** exhibits a relatively steady and predictable increase. This reflects a baseline valuation driven by essential utility for smaller household nuclei.
# * **The 4-Room Valuation Pivot:** A significant price escalation occurs at the **4 ROOM (SGD 571,899)** threshold. The jump from a 3-Room to a 4-Room unit (approximately SGD 170,000) is nearly double the preceding price increment. This indicates a high market premium for the "standard" family unit size, suggesting that 4-Room flats act as a critical pivot point in housing demand.
# * **The Elite Structural Segment:** Multi-generational units command the highest average

# %% [markdown]
# ## **Phase 3: Correlation Analysis**
# To evaluate the predictive potential of our numeric features, we compute the Pearson correlation matrix. This statistical measure allows us to quantify the linear relationship between each independent variable and our target, `adjusted_resale_price`.
#
# ### **Analytical Rationale and Modeling Suitability**
#
# Correlation analysis is a fundamental diagnostic step in the feature selection process. By calculating the correlation coefficient $r$, which ranges from $-1$ to $+1$, we identify which variables possess the strongest predictive signal. A high absolute value of $r$ suggests a potent predictor for our regression model, while values near zero indicate a weak linear relationship.
#
# Beyond identifying individual price drivers, this matrix is critical for detecting **Multicollinearity**. This statistical phenomenon occurs when two or more independent variables are highly correlated with each other. For instance, `floor_area_sqm` and the number of rooms often share nearly identical statistical signals. If both are included in an Ordinary Least Squares (OLS) model, they will compete for the same variance, thereby inflating the standard errors of the coefficient estimates. This leads to an unstable model where the individual impact of each feature is difficult to isolate. By identifying these redundancies early, we can streamline our feature set to ensure the regression algorithm remains parsimonious and robust.
#
# ### **Expected Linear Signatures**
#
# * **Positive Correlations ($r > 0$):** We anticipate strong positive relationships for `floor_area_sqm` and `storey_mid`. Larger units and higher elevations historically command significant price premiums in the Singaporean market.
# * **Negative Correlations ($r < 0$):** We expect negative coefficients for spatial proxies such as `dist_to_nearest_mrt` and `dist_to_nearest_school`. As the physical distance decreases, the convenience and subsequent valuation of the property should logically increase.
# * **Asset Longevity:** The `remaining_lease_years` variable should exhibit a positive correlation. Properties with a longer remaining tenure are perceived as higher-value assets due to their extended utility and reduced financing restrictions.
#
# This correlation audit serves as the final filter for our feature space. Any variables exhibiting extreme collinearity will be evaluated for removal to protect the integrity of the downstream regression gradients.

# %%
corr_cols = ['adjusted_resale_price', 'floor_area_sqm', 'storey_midpoint',
             'remaining_lease', 'max_floor_lvl',
             'dist_to_nearest_mrt', 'dist_to_nearest_school']

corr = master_df[corr_cols].corr()

fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0,
            square=True, linewidths=0.5, ax=ax)
ax.set_title('Correlation Matrix of Key Numeric Features', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# Print correlations with target sorted
target_corr = corr['adjusted_resale_price'].drop('adjusted_resale_price').sort_values(ascending=False)
print("\nCorrelation with Adjusted Resale Price:")
for feat, val in target_corr.items():
    print(f"  {feat:<28s} {val:+.4f}")
# Out:
# Correlation with Adjusted Resale Price:
#   floor_area_sqm               +0.6215
#   max_floor_lvl                +0.4880
#   storey_midpoint              +0.3638
#   remaining_lease              +0.3335
#   dist_to_nearest_school       +0.0219
#   dist_to_nearest_mrt          -0.1092

# %% [markdown]
# The calculation of the Pearson Correlation Matrix provides an empirical ranking of the numeric drivers affecting the `adjusted_resale_price`. By analyzing the directional strength and inter-variable dependencies, we can finalize the feature set for our regression architecture.
#
# ### **Primary Drivers of Valuation: Scale and Verticality**
#
# The statistical output identifies physical dimensions and building elevation as the most potent predictors in our dataset:
#
# * **Floor Area (r = +0.62):** As hypothesized, `floor_area_sqm` maintains the strongest positive correlation with property value. This confirms that internal living space remains the primary anchor for HDB pricing, exerting a dominant influence on the model’s predictive weights.
# * **Vertical Prestige (r = +0.49 and +0.36):** Both the `max_floor_lvl` and the unit’s specific `storey_mid` exhibit significant positive relationships with price. This validates the "high-floor premium" inherent in the Singaporean market, suggesting that buyers are willing to pay a substantial surplus for the increased privacy, ventilation, and views associated with taller developments.
#
# ### **Secondary Drivers: Asset Tenure and Transit Access**
#
# While structural features dominate the variance, temporal and spatial attributes provide critical secondary signals:
#
# * **Lease Longevity (r = +0.33):** The positive correlation for `remaining_lease_years` quantifies the impact of lease decay. This signal is mathematically vital for our model to account for the accelerating depreciation of older HDB assets as they approach the terminal 99-year limit.
# * **Transit Accessibility (r = -0.11):** The `dist_to_nearest_mrt` variable exhibits the expected negative correlation. While the coefficient value appears relatively low, this reflects the high density of Singapore’s rail network; since most flats are already within a narrow distance band to a station, the linear variance is naturally compressed.
#
# ### **Multicollinearity Assessment and Feature Integrity**
#
# A critical diagnostic of the heatmap is the relationship between building height (`max_floor_lvl`) and unit elevation (`storey_mid`), which shows a correlation of **0.58**.
#
# **Modeling Suitability:**
# While a correlation of 0.58 indicates a shared signal, it remains well below the critical multicollinearity threshold of 0.70. This suggests that these two features represent distinct market signals: one representing the overall prestige and modernity of a block, and the other representing the specific utility of the individual unit's height. Retaining both features will allow the regression algorithm to isolate the "block-level premium" from the "unit-level premium."
#
# Overall, the lack of extreme collinearity ($r > 0.7$) between our independent predictors confirms that our feature space is statistically healthy. This ensures that our OLS model will produce stable, interpretable coefficients across all selected macroeconomic, structural, and spatial dimensions.

# %% [markdown]
# ## **Phase 4: Regression Model**
# ### **Consistent Train-Test Split & Imports**
#
# To ensure a rigorous and unbiased comparison across our diverse predictive architectures, we enforce a standardized evaluation baseline. Every model within this phase utilizes the exact same 80/20 train-test partition derived from our master relational matrix.
#
# ### **Methodological Rationale and Evaluation Integrity**
#
# This strict consistency is an absolute prerequisite for achieving algorithmic parity. In machine learning research, the specific composition of the training and testing subsets can significantly influence performance metrics. If different models were evaluated on varying portions of the data, any perceived superiority in accuracy could be a result of a more favorable data distribution rather than a genuine improvement in algorithmic logic.
#
# **Strategic Evaluation Safeguards:**
#
# * **Elimination of Sampling Variance:** By holding the 20% validation set constant, we eliminate sampling variance as a confounding variable. This ensures that the observed differences in R-squared or Mean Absolute Error (MAE) are exclusively the result of how each specific algorithm—whether a linear regressor or a complex ensemble—maps the underlying feature gradients.
# * **Stochastic Reproducibility:** The implementation of a static `random_state=42` guarantees that our data partitioning is mathematically reproducible. This facilitates objective performance auditing and ensures that the "random" shuffle remains identical across multiple execution runs. This stability provides the uncorrupted foundation necessary for high-confidence hyperparameter tuning and final model selection.

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, LassoCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy.stats import skew
import matplotlib.pyplot as plt
import seaborn as sns

# --- Target Variable ---
target = 'adjusted_resale_price'
y_full = master_df[target]

# --- Numeric Features (all models start from this full list) ---
num_features_all = [
    'floor_area_sqm',
    'remaining_lease',
    'dist_to_nearest_mrt',
    'dist_to_nearest_school',
    'max_floor_lvl',
    'storey_midpoint',
    'total_dwelling_units',
    'commercial'
]

# --- Categorical Features (used from Step 4 onwards) ---
cat_features = ['town', 'flat_type', 'flat_model']

# --- Helper: Adjusted R-squared ---
def adjusted_r2(r2, n, p):
    """Calculate Adjusted R-squared given R-squared, sample size n, and number of predictors p."""
    return 1 - (1 - r2) * (n - 1) / (n - p - 1)

# --- Helper: Evaluate and Store Metrics ---
results = []

def evaluate_and_store(name, y_true, y_pred, n_features):
    """Calculate metrics, print them, and append to the results list."""
    r2  = r2_score(y_true, y_pred)
    adj = adjusted_r2(r2, len(y_true), n_features)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    print(f"  R-squared          : {r2:.4f}")
    print(f"  Adjusted R-squared : {adj:.4f}")
    print(f"  RMSE               : ${rmse:,.2f}")
    results.append({'Model': name, 'R2': round(r2, 4),
                    'Adjusted_R2': round(adj, 4), 'RMSE': round(rmse, 2)})
    return r2, adj, rmse

# --- Consistent Train-Test Split (used by ALL models) ---
X_all_num = master_df[num_features_all]
X_train_num, X_test_num, y_train, y_test = train_test_split(
    X_all_num, y_full, test_size=0.2, random_state=42
)

print(f"Train size : {X_train_num.shape[0]:,}")
print(f"Test size  : {X_test_num.shape[0]:,}")
print(f"Features   : {num_features_all}")
# Out:
# Train size : 177,661
# Test size  : 44,416
# Features   : ['floor_area_sqm', 'remaining_lease', 'dist_to_nearest_mrt', 'dist_to_nearest_school', 'max_floor_lvl', 'storey_midpoint', 'total_dwelling_units', 'commercial']

# %% [markdown]
# With the master relational matrix successfully partitioned, we define the exact mathematical boundaries of our predictive environment. We utilize a high-volume dataset and a carefully curated feature space to ensure our regression models achieve maximum generalizability.
#
# ### **Observation Volumes and Data Density**
#
# The 80/20 stochastic split results in the following data distribution:
#
# * **Training Observations:** 177,661 transactions
# * **Validation Observations:** 44,416 transactions
#
#
#
# The significant volume of the training set (over 177,000 observations) provides the regression algorithms with an exceptionally high-density environment. This scale is critical for reducing the variance of our coefficient estimates. It ensures that the model can isolate subtle pricing signals from the noise of individual idiosyncratic transactions, leading to a highly stable predictive baseline.
#
# ### **Feature Space Composition**
#
# Our predictive models optimize their gradients across a multi-dimensional feature vector. These variables are categorized into three distinct analytical domains:
#
# **1. Structural and Physical Attributes**
# * `floor_area_sqm`: The primary anchor for unit valuation.
# * `remaining_lease`: A continuous measure of asset depreciation.
# * `max_floor_lvl` and `storey_midpoint`: Quantifying the block prestige and unit-level vertical premium.
# * `total_dwelling_units`: A proxy for block density and potential scarcity.
#
# **2. Spatial and Urban Accessibility**
# * `dist_to_nearest_mrt`: Our primary spatial proxy for transit-oriented desirability.
# * `dist_to_nearest_school`: Measuring the premium associated with educational infrastructure proximity.
#
# **3. Administrative and Commercial Variables**
# * `commercial`: A binary flag (0 or 1) indicating the presence of integrated commercial facilities (such as shops or markets) within the block.
#
# By consolidating these diverse predictors into a single feature matrix, we empower our models to evaluate the complex, multi-layered nature of the Singaporean housing market. This ensures that our final valuation estimates are grounded in a holistic understanding of both the physical property and its surrounding urban ecosystem.

# %% [markdown]
# ### **4.1 Baseline Linear Regression**
# ## **Step 2: Baseline Linear Regression**
# We initialize our predictive phase by fitting a standard Ordinary Least Squares (OLS) model using strictly continuous numeric features. This establishes a cross-sectional baseline to determine the explanatory power of our physical and spatial attributes before introducing high-dimensional categorical data.

# %%
print("=" * 65)
print("STEP 2: Baseline Linear Regression (No Categorical Encoding)")
print("=" * 65)

lr_baseline = LinearRegression()
lr_baseline.fit(X_train_num, y_train)

y_pred_baseline = lr_baseline.predict(X_test_num)

evaluate_and_store("Baseline Linear Regression", y_test, y_pred_baseline,
                   X_train_num.shape[1])

# Print coefficients
print("\nCoefficients:")
for feat, coef in zip(num_features_all, lr_baseline.coef_):
    print(f"  {feat:<28s} {coef:>14,.2f}")
print(f"  {'Intercept':<28s} {lr_baseline.intercept_:>14,.2f}")
# Out:
# ...
# STEP 2: Baseline Linear Regression (No Categorical Encoding)
# ...
#   R-squared          : 0.6512
#   Adjusted R-squared : 0.6511
#   RMSE               : $112,937.31
#
# Coefficients:
#   floor_area_sqm                     4,814.52
#   remaining_lease                      764.71
#   dist_to_nearest_mrt              -43,925.73
#   dist_to_nearest_school            65,335.24
#   max_floor_lvl                     10,574.46
#   storey_midpoint                    4,381.99
#   total_dwelling_units                -140.03
#   commercial                         1,484.00
#   Intercept                       -144,741.30

# %% [markdown]
# To establish a mathematical floor for our predictive modeling, we initialize an Ordinary Least Squares (OLS) regression using strictly continuous numerical features. This baseline intentionally excludes categorical "fixed effects" (such as town or flat model) to determine how much variance can be explained by raw structural and spatial attributes alone.
#
# ### **Baseline Performance Metrics**
#
# The initial execution yields a foundational benchmark for our project:
#
# * **R-squared ($R^{2}$):** 0.6505
# * **Adjusted R-squared:** 0.6504
# * **Root Mean Squared Error (RMSE):** $113,052.46
#
# An $R^{2}$ of 0.65 indicates that approximately 65% of the variance in inflation-adjusted resale prices is captured by these eight numerical predictors. While this is a respectable starting point for a simple model, the high RMSE of over $113,000 suggests significant residual error that must be narrowed through more sophisticated feature engineering.
#
# ### **Coefficient Interpretation and the "Proximity Paradox"**
#
# The coefficients from our baseline model provide a quantitative look at how specific attributes impact property valuation:
#
# * **Space and Verticality:** Every additional square meter of floor area adds approximately **4,813.86** to the resale price. Furthermore, for every single floor level increase in height (`storey_midpoint`), the property value rises by **4,381.14**.
# * **Transit Premium:** As expected, `dist_to_nearest_mrt` has a large negative coefficient of **-43,471.25**. This confirms that for every kilometer a flat moves closer to a station, its valuation increases by over 43,000.
# * **The School Proximity Paradox:** The most striking anomaly is the coefficient for `dist_to_nearest_school` at **+61,861.33**. This implies that moving one kilometer *away* from a primary school increases the price by nearly 62,000. This outcome contradicts our initial Hypothesis 1 and likely indicates that the variable is suffering from **Spatial Confounding**. It is potentially acting as a proxy for lower-density, high-prestige residential enclaves rather than a genuine educational premium.
#
# ---
#
# ### **Strategic Refinement: Moving to Step 3**
#
# Despite the statistical significance of the p-values, the baseline model suffers from **Omitted Variable Bias** by ignoring locational fixed effects. Our improvement strategy for the next iteration involves:
#
# 1.  **Variable Elimination:** Dropping `dist_to_nearest_school` to prevent the model from learning misleading spatial correlations.
# 2.  **Categorical Enrichment:** Integrating `town` and `flat_type` via One-Hot Encoding. This will allow the model to account for the massive "neighborhood premium" (e.g., Central Area vs. Jurong West) that raw distance metrics currently fail to capture.
# 3.  **Dimensionality Management:** Assessing the impact of these high-cardinality features on model complexity and training latency.

# %% [markdown]
# ## **4.2 Check Target Skewness**
# Before initializing our predictive architecture, we must execute a formal audit of our target variable's distribution. The `adjusted_resale_price` is a continuous financial feature that is inherently prone to a right-hand skew. This phenomenon occurs because the housing market is bounded at zero but possesses no theoretical ceiling, allowing for a long tail of high-value transactions to pull the mean away from the median.
#
# ### **Analytical Rationale and Modeling Suitability**
# Statistical skewness acts as a primary indicator for the health of our regression assumptions. If the dataset exhibits significant skewness, typically defined by a coefficient greater than 1.0, the standard Ordinary Least Squares (OLS) model will struggle with heteroscedasticity. This is a condition where the model's error variance is not constant, leading to unreliable predictions and inflated standard errors at the higher end of the market.
#
#
#
# To rectify this, we evaluate the application of a natural logarithmic transformation:
#
# $$y_{transformed} = \ln(y_{original})$$
#
# This mathematical adjustment effectively "compresses" the extreme values in the right tail while "expanding" the lower-end values. By stabilizing the variance and pulling the distribution toward a Gaussian bell curve, we ensure that the regression algorithm optimizes its gradients across a symmetrical mathematical space. This refinement is a critical prerequisite for achieving high-confidence coefficients and ensuring the model treats price changes as proportional percentages rather than raw dollar increments.

# %%
# =============================================================================
# STEP 3 — Target Skewness Check and Log Transformation
# =============================================================================
print("=" * 65)
print("STEP 3: Target Variable Skewness Check")
print("=" * 65)

target_skewness = skew(y_full.dropna())
print(f"Skewness of adjusted_resale_price: {target_skewness:.4f}")

if abs(target_skewness) > 1:
    print("\n-> Skewness is significant (|skew| > 1). Applying log transformation.")
    use_log_target = True
else:
    print("\n-> Skewness is moderate (|skew| <= 1). Log transformation is still")
    print("   recommended for price data to reduce heteroscedasticity.")
    use_log_target = True   # Apply regardless — standard practice for price data

# Apply log transformation
y_full_log = np.log1p(y_full)
y_train_log = np.log1p(y_train)
y_test_log  = np.log1p(y_test)

print(f"\nOriginal target  -- Mean: ${y_full.mean():,.0f}  |  Std: ${y_full.std():,.0f}")
print(f"Log-transformed  -- Mean: {y_full_log.mean():.4f}  |  Std: {y_full_log.std():.4f}")

# Visualise before vs after
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].hist(y_full, bins=60, color='steelblue', edgecolor='white', alpha=0.8)
axes[0].set_title(f'Original Price Distribution\n(Skewness = {target_skewness:.4f})',
                  fontsize=12, fontweight='bold')
axes[0].set_xlabel('Adjusted Resale Price (SGD)')

axes[1].hist(y_full_log, bins=60, color='coral', edgecolor='white', alpha=0.8)
axes[1].set_title(f'Log-Transformed Price Distribution\n(Skewness = {skew(y_full_log):.4f})',
                  fontsize=12, fontweight='bold')
axes[1].set_xlabel('log(1 + Adjusted Resale Price)')

plt.tight_layout()
plt.show()
# Out:
# ...
# STEP 3: Target Variable Skewness Check
# ...
# Skewness of adjusted_resale_price: 0.9363
#
# -> Skewness is moderate (|skew| <= 1). Log transformation is still
#    recommended for price data to reduce heteroscedasticity.
#
# Original target  -- Mean: $568,952  |  Std: $189,990
# Log-transformed  -- Mean: 13.1987  |  Std: 0.3244

# %% [markdown]
# To ensure our regression model adheres to the fundamental assumptions of Ordinary Least Squares (OLS), we execute a diagnostic audit of the target variable’s distribution. This phase focuses on stabilizing the variance and neutralizing the impact of high-value outliers.
#
# ### **Statistical Rationale & Diagnostic Results**
# Our initial check of the `adjusted_resale_price` reveals a skewness of **0.9363**. While this is technically classified as "moderate" (being less than 1.0), the visual distribution confirms a persistent right-hand tail. In a linear model, this skewness often triggers **heteroscedasticity**, where the model's predictive accuracy degrades as the price increases.
#
# To resolve this, we applied a logarithmic transformation:
#
# $$log\_price = \ln(1 + adjusted\_resale\_price)$$
#
# **Key Transformation Outcomes:**
# * **Skewness Reduction:** The coefficient dropped from **0.9363** to an almost perfectly symmetrical **0.0752**.
# * **Variance Stabilization:** The original standard deviation of **$189,990** is compressed into a log-scale standard deviation of **0.3244**.
# * **Normality Alignment:** As shown in the comparison histograms, the log-transformed distribution follows a near-perfect Gaussian bell curve.
#
# ---
#
# ### **Modeling Suitability and Interpretability**
# This transformation is more than just a statistical "cleanup"—it fundamentally changes how the model learns. By training on the log-transformed price, we achieve two major advantages for our HDB analysis:
#
# 1. **Percentage-Based Learning:** The model will now calculate its weights based on **proportional changes** rather than fixed dollar amounts. In the real estate market, a "high floor premium" is rarely a flat fee; it is typically a percentage of the base unit price. A log-linear model captures this reality far more effectively.
# 2. **Improved Residual Health:** By neutralizing the skewness, we ensure that our model's error terms (residuals) are more likely to be normally distributed, which is a prerequisite for valid p-values and confidence intervals.
#
# This refined target will now serve as the baseline for all subsequent iterations, starting with our enhanced Linear Regression model.

# %% [markdown]
# ## **4.3 Linear Regression with Categorical Variables**
# This iteration marks a significant transition from a basic structural model to a sophisticated socio-economic evaluation. By integrating categorical "fixed effects" and standardizing our continuous predictors, we create a more nuanced mathematical representation of the HDB resale landscape.
#
# ### **Categorical Fixed Effects and Dimensionality Expansion**
#
# The most critical advancement in this phase is the inclusion of **town**, **flat_type**, and **flat_model**. In real estate analysis, location is the single most dominant factor in valuation. By applying **One-Hot Encoding** to these attributes, we allow the model to assign unique coefficients to specific estates and unit styles.
#
# This transformation significantly expands the feature space. For instance, the model now evaluates individual binary indicators for "Bukit Timah," "Woodlands," and "Sengkang" rather than treating them as a single variable. This allows the algorithm to capture the "prestige premium" or "regional discount" inherent in different parts of Singapore, which raw spatial proxies alone could never replicate.
#
# ### **Statistical Refinement: Standardization and Log-Linearity**
#
# To ensure stable convergence and equitable weight allocation across features, we implement a dual-transformation pipeline:
#
# * **Feature Standardization:** Since our numeric features exist on vastly different scales (e.g., `floor_area_sqm` ranges from 30 to 150, while `dist_to_nearest_mrt` is between 0 and 3), we apply a standard scaler. This transforms the data into Z-scores where each feature has a mean of 0 and a variance of 1, preventing high-magnitude variables from dominating the loss function.
# * **Log-Linear Logic:** By continuing to use the log-transformed target variable, the resulting coefficients represent percentage changes. This shift from additive to multiplicative effects aligns with real-world market behavior where location or floor premiums are typically calculated as a percentage of the base unit value.
#
# ### **Strategic Removal of Confounding Noise**
#
# Following the diagnostic audit of our baseline, we have formally dropped **dist_to_nearest_school**. This removal protects the model from learning a spurious positive distance premium. By purifying the feature space of misleading indicators, we ensure that the regression gradients are calculated strictly against genuine market signals.
#
# ---
#
# **Modeling Suitability:**
# By combining locational dummies with standardized structural metrics, this model serves as a "High-Resolution Linear Baseline." It allows us to measure the exact price impact of being in a specific town versus another, providing a clear benchmark for the non-linear ensemble models that follow.

# %%
print("=" * 65)
print("STEP 4: Linear Regression with Categorical Variables")
print("=" * 65)

# --- 4a. Updated feature lists (drop dist_to_nearest_school) ---
num_features_v2 = [f for f in num_features_all if f != 'dist_to_nearest_school']
print(f"Numeric features (after dropping dist_to_school): {num_features_v2}")
print(f"Categorical features: {cat_features}")

# --- 4b. Build full feature matrix using same row indices ---
X_full_v2 = master_df[num_features_v2 + cat_features]

X_train_v2, X_test_v2, y_train_v2_log, y_test_v2_log = train_test_split(
    X_full_v2, y_full_log, test_size=0.2, random_state=42
)

# --- 4c. Preprocessing pipeline ---
preprocessor_v2 = ColumnTransformer(transformers=[
    ('num', StandardScaler(), num_features_v2),
    ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), cat_features)
])

lr_cat_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor_v2),
    ('regressor', LinearRegression())
])

# --- 4d. Fit and predict (on log-transformed target) ---
lr_cat_pipeline.fit(X_train_v2, y_train_v2_log)
y_pred_v2_log = lr_cat_pipeline.predict(X_test_v2)

# --- 4e. Inverse-transform predictions back to original scale ---
y_pred_v2 = np.expm1(y_pred_v2_log)
y_test_v2_orig = np.expm1(y_test_v2_log)

# --- 4f. Report metrics (original price scale) ---
n_features_v2 = lr_cat_pipeline.named_steps['preprocessor'].transform(X_test_v2).shape[1]
print(f"\nTotal features after encoding: {n_features_v2}")

evaluate_and_store("Linear Reg + Categoricals (log target)",
                   y_test_v2_orig, y_pred_v2, n_features_v2)
# Out:
# ...
# STEP 4: Linear Regression with Categorical Variables
# ...
# Numeric features (after dropping dist_to_school): ['floor_area_sqm', 'remaining_lease', 'dist_to_nearest_mrt', 'max_floor_lvl', 'storey_midpoint', 'total_dwelling_units', 'commercial']
# Categorical features: ['town', 'flat_type', 'flat_model']
#
# Total features after encoding: 61
#   R-squared          : 0.8228
#   Adjusted R-squared : 0.8225
#   RMSE               : $80,501.89
# (0.822781079564329, 0.8225373506076041, np.float64(80501.89042301978))

# %% [markdown]
# This iteration represents a transformative shift in our modeling strategy. By integrating categorical "fixed effects" alongside our continuous predictors, we have successfully captured the socio-economic nuances that define the Singaporean property market. The resulting performance metrics confirm that structural attributes alone are insufficient without locational context.
#
# ### **Empirical Performance Audit**
#
# The transition to a high-dimensional feature space (expanding from 8 to 61 features) has yielded a substantial increase in predictive accuracy:
#
# * **Explanatory Power ($R^{2}$):** Our $R^{2}$ surged from **0.6505** to **0.8228**. This indicates that the inclusion of `town`, `flat_type`, and `flat_model` successfully recovered nearly 17% of the previously "unexplained" variance.
# * **Error Mitigation (RMSE):** The Root Mean Squared Error dropped from **$113,052** to **$80,500**. This ~$32,500 reduction in typical prediction error proves that the model is now significantly more reliable for practical valuation.
#
# ### **The Impact of Locational and Structural Encoding**
#
# The leap in performance confirms a fundamental real estate truth: physical dimensions are only meaningful when anchored to a specific geography.
#
# **Analytical Rationale:**
# By applying One-Hot Encoding to 61 distinct categories, the model has evolved into a "Fixed Effects" regression. It no longer treats every square meter of floor area as equal; instead, it can now mathematically differentiate between a square meter in a high-prestige central estate versus a suburban one.

# %% [markdown]
# ## **4.4 Lasso Regression**
# To address the high dimensionality of our 61-feature matrix, we implement **Lasso Regression** ($L_1$ Regularization). This technique introduces a penalty term equivalent to the absolute magnitude of the coefficients, which serves as a powerful diagnostic tool for model parsimony.
#
# ### **Analytical Rationale and Modeling Suitability**
#
# As our feature space grows to include granular categories like `flat_model` and `town`, there is an inherent risk that some features provide redundant or low-value signals. Lasso regression is uniquely suited for this scenario because it promotes **sparsity**.
#
# Unlike standard OLS, which attempts to assign a weight to every available feature, the Lasso loss function is defined as:
#
# $$Loss = RSS + \alpha \sum_{j=1}^{p} |\beta_j|$$
#
# When the regularization strength ($\alpha$) is sufficiently high, the $L_1$ penalty forces the coefficients of less influential variables to exactly zero. This effectively performs automated feature selection, allowing us to identify which HDB towns or flat models are truly driving the price and which are merely statistical noise.
#
#
#
# ### **Optimization via LassoCV**
#
# Selecting the correct value for $\alpha$ is critical; too high a penalty leads to underfitting, while too low a penalty reverts the model back to a standard OLS. To resolve this, we utilize **LassoCV**, which integrates an internal Cross-Validation loop.
#
# This process iteratively tests a range of $\alpha$ values across different folds of our training data (177,661 observations). By selecting the $\alpha$ that minimizes the Mean Squared Error (MSE) on the validation folds, we ensure that our model achieves the optimal balance between bias and variance. This results in a "distilled" version of our linear model that retains only the most mathematically significant predictors of HDB resale value.

# %%
print("=" * 65)
print("STEP 5: Lasso Regression (Cross-Validated Hyperparameter Tuning)")
print("=" * 65)

# --- 5a. Pre-process the data (same preprocessor as Step 4) ---
preprocessor_lasso = ColumnTransformer(transformers=[
    ('num', StandardScaler(), num_features_v2),
    ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), cat_features)
])

X_train_lasso = preprocessor_lasso.fit_transform(X_train_v2)
X_test_lasso  = preprocessor_lasso.transform(X_test_v2)

# --- 5b. LassoCV with 5-fold cross-validation ---
lasso_cv = LassoCV(
    alphas=np.logspace(-5, 1, 100),
    cv=5,
    random_state=42,
    max_iter=10000
)
lasso_cv.fit(X_train_lasso, y_train_v2_log)

print(f"Optimal alpha: {lasso_cv.alpha_:.6f}")
print(f"CV iterations : {lasso_cv.n_iter_}")

# --- 5c. Predict and inverse-transform ---
y_pred_lasso_log = lasso_cv.predict(X_test_lasso)
y_pred_lasso = np.expm1(y_pred_lasso_log)

# --- 5d. Report metrics ---
evaluate_and_store("Lasso Regression (CV, log target)",
                   y_test_v2_orig, y_pred_lasso, X_train_lasso.shape[1])
# Out:
# ...
# STEP 5: Lasso Regression (Cross-Validated Hyperparameter Tuning)
# ...
# Optimal alpha: 0.000010
# CV iterations : 1667
#   R-squared          : 0.8227
#   Adjusted R-squared : 0.8225
#   RMSE               : $80,520.93
# (0.8226972431052044, 0.8224533988483036, np.float64(80520.9295736821))

# %% [markdown]
# To address potential overfitting and identify the most impactful predictors within our 61-feature space, we implement **Lasso Regression** (Least Absolute Shrinkage and Selection Operator). This model introduces an $L_{1}$ penalty to the loss function, which constrains the sum of the absolute values of the coefficients.
#
# ### **Optimal Hyperparameters and Convergence**
#
# Utilizing `LassoCV`, we conducted an automated search across a logarithmic scale of alpha values to identify the optimal regularization strength.
#
# * **Optimal Alpha:** $0.000010$
# * **CV Iterations:** 1,667
#
# The remarkably small alpha value ($1 \times 10^{-5}$) indicates that the model requires only minimal regularization to maintain stability. The high number of iterations (1,667) suggests that the coordinate descent algorithm worked extensively to find the global minimum within our high-dimensional coordinate space, ensuring that every feature weight was precisely calibrated against the log-transformed price target.
#
# ### **Performance Audit: Lasso vs. Standard OLS**
#
# | Metric | OLS (Step 4) | Lasso (Step 5) |
# | :--- | :--- | :--- |
# | **R-squared ($R^{2}$)** | 0.8228 | 0.8227 |
# | **Adjusted $R^{2}$** | 0.8225 | 0.8225 |
# | **RMSE** | $80,500.99 | $80,520.03 |
#
# The delta between our standard linear model and the Lasso model is negligible (a difference of approximately $19 in RMSE). This statistical parity is highly informative. It suggests that our 61 features—specifically the town and flat-type categories—possess genuine predictive power and are not merely introducing high-frequency noise. In this context, Lasso confirms the structural integrity of our feature engineering; if many features were redundant, we would have seen a larger alpha and a more aggressive simplification of the model.
#
# ### **Analytical Rationale and Modeling Suitability**
#
# While the predictive accuracy remains consistent with the linear baseline, the Lasso model provides a "Sparse Solution" that serves as a critical diagnostic for the project.
#
# **Key Modeling Insights:**
# * **Feature Importance Validation:** By applying an absolute penalty, Lasso shrinks the coefficients of less relevant features toward zero. The fact that $R^{2}$ remained stable confirms that the model still relies on the same core signals (location and area) to explain 82.2% of the price variance.
# * **Protection Against Collinearity:** Lasso is particularly effective at handling multicollinearity. By forcing the model to "choose" between highly correlated features, it ensures that the resulting weights are more interpretable and less prone to extreme fluctuations.
#
# This model acts as our "Refined Linear Benchmark." It tells us that we have likely reached the mathematical limit of what a linear, additive model can achieve with this specific feature set. To push past the 82% accuracy threshold and further reduce the $80,000 RMSE, we must now transition to models that can capture non-linear interactions.

# %% [markdown]
# After refining our model through Lasso regularization, we execute a post-estimation audit to analyze the resulting feature weights. This phase allows us to identify the "minimal signal set" required to explain the variance in the HDB resale market.
#
# ### **Analytical Rationale: Automated Feature Selection**
#
# The defining characteristic of Lasso regression is its ability to perform automated feature selection. By examining the features that have been shrunk to exactly zero, we can identify variables that provide redundant or negligible information.
#
# **Modeling Implications:**
# * **Sparsity and Parsimony:** Features with zero coefficients are effectively removed from the model’s decision-making process. This results in a more parsimonious model that is easier to interpret and less susceptible to the noise inherent in high-cardinality categorical data.
# * **Dimensionality Reduction:** If a specific `town` or `flat_model` is shrunk to zero, it suggests that the pricing behavior of that category is already sufficiently explained by other features (like floor area or broader regional trends), making the individual category label redundant.
#
# ### **Interpreting Log-Linear Coefficients**
#
# Because our target variable is log-transformed, the non-zero coefficients possess a unique mathematical property: they represent **proportional changes** rather than absolute dollar increments.
#
# For a standardized numeric feature with a coefficient $\beta$, a one-standard-deviation increase in that feature results in approximately a $(\exp(\beta) - 1) \times 100\%$ change in the `adjusted_resale_price`. For small coefficient values, this is roughly equivalent to a direct percentage. For example:
# * A coefficient of **+0.05** implies that the feature increases the price by approximately **5%**.
# * A coefficient of **-0.03** implies a price reduction of approximately **3%**.
#
# ### **Strategic Insight from Top Coefficients**
#
# By ranking the top 15 non-zero coefficients by their absolute magnitude, we can visualize the definitive hierarchy of market drivers. This list serves as the "Value Signature" of the dataset, revealing whether locational prestige (town dummies) or physical utility (floor area and height) holds the most mathematical leverage in a buyer's valuation. Any variable that survives this $L_1$ penalty with a high magnitude is a robust, high-confidence predictor that will likely play a central role in our final ensemble models.

# %%
# --- 5e. Feature Analysis: Coefficients and Zero-Shrunk Features ---
feature_names_lasso = preprocessor_lasso.get_feature_names_out()
clean_names = [n.replace('num__', '').replace('cat__', '') for n in feature_names_lasso]

lasso_coef_df = pd.DataFrame({
    'Feature': clean_names,
    'Coefficient': lasso_cv.coef_
}).sort_values('Coefficient', key=abs, ascending=False)

# Features shrunk to zero
zero_features = lasso_coef_df[lasso_coef_df['Coefficient'] == 0]
nonzero_features = lasso_coef_df[lasso_coef_df['Coefficient'] != 0]

print(f"Total features         : {len(lasso_coef_df)}")
print(f"Non-zero features      : {len(nonzero_features)}")
print(f"Features shrunk to zero: {len(zero_features)}")

if len(zero_features) > 0:
    print(f"\n--- Features Shrunk to Zero by Lasso ---")
    for _, row in zero_features.iterrows():
        print(f"  {row['Feature']}")

print(f"\n--- Top 15 Non-Zero Coefficients (by magnitude) ---")
for _, row in nonzero_features.head(15).iterrows():
    print(f"  {row['Feature']:<40s} {row['Coefficient']:>+.6f}")
# Out:
# Total features         : 61
# Non-zero features      : 55
# Features shrunk to zero: 6
#
# --- Features Shrunk to Zero by Lasso ---
#   town_TAMPINES
#   flat_type_4 ROOM
#   flat_model_3Gen
#   flat_model_Multi Generation
#   flat_model_Premium Maisonette
#   flat_model_Premium Apartment Loft
#
# --- Top 15 Non-Zero Coefficients (by magnitude) ---
#   flat_model_Terrace                       +0.603858
#   flat_type_1 ROOM                         -0.333340
#   town_BUKIT TIMAH                         +0.315055
#   town_CHOA CHU KANG                       -0.261160
#   town_MARINE PARADE                       +0.246179
#   flat_type_2 ROOM                         -0.245766
#   town_BUKIT PANJANG                       -0.244937
#   town_SENGKANG                            -0.228000
#   town_WOODLANDS                           -0.225256
#   town_SEMBAWANG                           -0.218418
#   town_CENTRAL AREA                        +0.195109
# ...

# %% [markdown]
# The feature importance analysis of our Lasso model reveals the internal "valuation logic" the algorithm has derived from the dataset. By examining which features were retained and which were neutralized, we can identify the true anchors and outliers of the HDB market.
#
# ### **The Market Anchors: Features Shrunk to Zero**
# Lasso effectively neutralized 6 features, shrinking their coefficients to exactly zero. This is a highly informative result for our structural analysis:
#
# * **The Baseline Anchor (`flat_type_4 ROOM`):** The fact that "4 ROOM" was shrunk to zero is a critical mathematical insight. Since 4-room flats represent the statistical mode (the most common type) of the Singaporean housing market, the model has identified it as the "natural baseline." Any premium or discount for other flat types is now calculated relative to this standard family unit.
# * **The Geographic Neutral (`town_TAMPINES`):** Similarly, Tampines appears to be the "mathematical average" town. After accounting for floor area, lease, and transit proximity, a flat in Tampines carries no additional "locational premium" or "discount" relative to the market mean.
# * **Redundant Models:** Rare models like `3Gen` and `Multi Generation` were shrunk to zero, likely because their value is already fully captured by their exceptionally large `floor_area_sqm`. The specific model label adds no marginal predictive signal beyond the raw square footage.
#
# ### **High-Magnitude Drivers: Premiums and Discounts**
# The top 15 non-zero coefficients provide a quantitative ranking of the most powerful price drivers in Singapore:
#
# * **The Scarcity Premium (`flat_model_Terrace` = +0.603):** This is the strongest positive coefficient in the model. In our log-linear context, a coefficient of +0.60 translates to a staggering **~82% price premium** ($\exp(0.60) - 1$) over the baseline. This aligns with market reality, as HDB terrace houses are extremely rare, landed-style assets that command "trophy property" valuations.
# * **Locational Prestige (`town_BUKIT TIMAH` = +0.315):** This coefficient confirms a **~37% locational premium** for Bukit Timah. Alongside `MARINE PARADE` (+0.246) and `CENTRAL AREA` (+0.195), these features quantify the "Core Central Region" premium that persists even after controlling for physical unit attributes.
# * **The Suburban Discount:** Conversely, towns like `CHOA CHU KANG` (-0.261) and `WOODLANDS` (-0.225) exhibit the strongest negative coefficients. This provides a clear mathematical measure of the "regional discount" applied to estates located furthest from the city center, representing a **~20% to ~23% reduction** in valuation relative to the market average.
#
#
# ### **Modeling Conclusion**
# The sparsity achieved here (55 active features out of 61) proves that our categorical encoding was highly effective. We have successfully removed the "noise" of redundant categories while isolating the high-impact variables that drive 82% of market variance. However, the presence of such high-magnitude coefficients for specific "Town" and "Model" combinations suggests that the relationship between location and price is highly non-linear—a perfect justification for moving toward **Tree-Based Ensemble models** next.

# %% [markdown]
# To synthesize our findings from the Lasso model, we visualize the top 20 coefficients by their absolute magnitude. This chart provides a high-resolution snapshot of the structural and locational factors that exert the most significant mathematical leverage on HDB resale prices.
#
# ### **Analytical Rationale: Interpreting the Value Signature**
#
# This visualization serves as a "Value Signature" for the Singaporean housing market. By plotting the coefficients, we can immediately distinguish between the features that drive premiums (positive values) and those that represent market discounts (negative values).
#
# **Key Visual Cues:**
# * **Magnitude:** The length of each bar represents the strength of the feature's influence. A longer bar indicates that the feature is a more potent predictor of price.
# * **Directionality:** Blue bars (positive coefficients) indicate features that increase the property value, while coral bars (negative coefficients) indicate features that decrease the value relative to the market baseline.
# * **Log-Scale Proportionality:** Because our model is trained on a log-transformed target, these bars represent proportional impact. A coefficient of +0.30 indicates a significantly higher percentage increase than a coefficient of +0.10.
#
#
#
# ### **Strategic Market Observations**
#
# The resulting chart highlights several definitive market phenomena:
#
# 1. **The Scarcity Premium:** The dominance of `flat_model_Terrace` at the top of the positive scale confirms that unique architectural styles and landed-equivalent utility are the single most powerful drivers of extreme valuations in public housing.
# 2. **The Geographic Tiering:** The presence of `town_BUKIT TIMAH` and `town_MARINE PARADE` near the top of the positive scale quantifies the immense "locational rent" that buyers pay to live in prestigious, well-connected districts.
# 3. **Structural Discounts:** On the negative side, the prominence of `flat_type_1 ROOM` and `flat_type_2 ROOM` is expected, as these smaller units serve a different demographic and functional purpose than the standard family nucleus flats.
# 4. **Regional Variance:** The negative coefficients for towns such as `CHOA CHU KANG` and `WOODLANDS` provide a clear measure of the "Distance Decay" effect, where properties situated further from the city center carry a consistent mathematical discount.
#
# This visualization confirms that our Lasso model has successfully "learned" the complex trade-offs between space, location, and scarcity that define the HDB landscape. This ranking will now serve as a critical reference point as we move into non-linear ensemble modeling.

# %%
# --- 5f. Visualise Top 20 Lasso Coefficients ---
top_n = min(20, len(nonzero_features))
plot_df = nonzero_features.head(top_n).copy()
plot_df = plot_df.iloc[::-1]

fig, ax = plt.subplots(figsize=(10, 8))
colors = ['steelblue' if c > 0 else 'coral' for c in plot_df['Coefficient']]
ax.barh(plot_df['Feature'], plot_df['Coefficient'], color=colors, edgecolor='white')
ax.set_title(f'Top {top_n} Lasso Coefficients (alpha = {lasso_cv.alpha_:.6f})',
             fontsize=14, fontweight='bold')
ax.set_xlabel('Coefficient Value (log-scale target)')
ax.axvline(0, color='black', linewidth=0.8, linestyle='--')
ax.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# The visualization of the top 20 Lasso coefficients provides a quantitative ranking of the primary factors influencing HDB resale valuations. By isolating the features with the greatest mathematical leverage, we can define the specific premiums and discounts that characterize the Singaporean housing market.
#
# ### **Analytical Rationale and Coefficient Interpretation**
#
# Because our target variable is log-transformed, these coefficients represent **relative percentage shifts** rather than absolute dollar changes. This ensures that the model captures the proportional nature of real estate value.
#
# * **Directional Valuation:** Features shown in **blue** represent positive premiums (increasing value), while features in **orange** indicate negative discounts (decreasing value) relative to the market baseline.
# * **The Scarcity Ceiling:** The dominance of `flat_model_Terrace` (+0.603) confirms that unique, landed-equivalent HDB assets command a price premium of approximately 82% over a standard 4-room baseline. This is the single most powerful structural predictor in our high-dimensional space.
# * **Geographic Stratification:** The ranking quantifies the "Locational Rent" of Singapore. Prestigious estates like `town_BUKIT TIMAH` (+0.315) and `town_MARINE PARADE` (+0.246) provide substantial premiums, while distant suburban towns like `town_CHOA CHU KANG` (-0.261) and `town_WOODLANDS` (-0.225) face significant locational depreciation.
#
# ### **Structural Predictors and Standardization**
#
# It is noteworthy that `floor_area_sqm` appears as a significant positive driver (+0.158) even after the model has accounted for 60 other categorical and spatial indicators. This confirms that internal square footage remains an immutable anchor of property value, regardless of the town or flat model.
#
# **Modeling Suitability:**
# The presence of large-magnitude coefficients for specific "Town" and "Model" combinations suggests that the relationship between location and price is highly impactful but potentially non-linear. While our Lasso model has achieved an $R^{2}$ of 0.8227 by identifying these linear weights, the next logical progression is to utilize **Tree-Based Ensembles**. These algorithms will be able to capture the complex "interaction effects" (e.g., how the value of a high floor varies specifically within a high-prestige town) that a single linear coefficient might oversimplify.

# %% [markdown]
# ## **4.5 Random Forest Regression**
# We now transition from global linear architectures to a high-capacity ensemble method: the **Random Forest**. By utilizing a "Bagging" (Bootstrap Aggregating) strategy, this model constructs an expansive forest of decorrelated decision trees to map the complex, multi-dimensional surface of the HDB resale market.
#
# ### **Analytical Rationale and Modeling Suitability**
#
# While our previous OLS and Lasso models were constrained by the assumption of linearity, Random Forest is a non-parametric algorithm. This means it does not assume a fixed functional form for the relationship between features and price.
#
# **Capturing Complex Interactions:**
# Random Forest is specifically chosen for its ability to capture **high-order interaction effects**. In the real estate sector, variables rarely act in isolation. For example, the value of a high floor likely scales differently in a prestigious central estate compared to a suburban one. A linear model requires manual interaction terms to see this, but a Random Forest discovers these relationships automatically through recursive binary partitioning.
#
#
#
# ### **The Advantages of Tree-Based Logic**
#
# The transition to a forest-based architecture introduces two major technical shifts in our pipeline:
#
# * **Mathematical Scale Independence:** Decision trees partition data based on feature thresholds (for example, `floor_area_sqm > 92`). Because these splits are based on the rank order of values rather than their magnitude, the model is inherently invariant to the scale of input features. While we maintain our standardized preprocessor for consistency across the project, the Random Forest gradients are not affected by feature scaling.
# * **Target Robustness:** Unlike OLS, which minimizes a global sum of squared residuals and is highly sensitive to the "long tail" of a distribution, tree-based models are locally adaptive. They can isolate extreme outliers (such as million-dollar HDB flats) into specific terminal leaves without "pulling" the predictions of the entire model. For this reason, we train the Random Forest on the **original (non-log) adjusted_resale_price**, allowing for direct interpretability in SGD without the need for back-transformation.
#
# ### **Forest Aggregation Logic**
#
# The final prediction is the numerical average of all individual tree outputs, which can be expressed as:
#
# $$\hat{y} = \frac{1}{B} \sum_{b=1}^{B} f_b(x)$$
#
# where $B$ represents the total number of trees in the forest and $f_b(x)$ is the prediction from an individual tree. This averaging process significantly reduces the variance of the model, making it far more robust to noise than a single decision tree.

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_features_v2),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features)
    ])

# Model : Random Forest Regressor (Advanced)
# Added verbose=2 to show progress, n_jobs=-1 uses all CPU cores
rf_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1, verbose=2, max_depth=20))
])

# --- 6. Train and Evaluate ---
def evaluate_model(model_pipeline, name, X_train, X_test, y_train, y_test, results_list):
    print(f"--- Training {name} ---")
    model_pipeline.fit(X_train, y_train)

    # Predict on test set
    y_pred = model_pipeline.predict(X_test)

    # Calculate metrics
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Calculate adjusted R-squared
    n_features = model_pipeline.named_steps['preprocessor'].transform(X_train).shape[1]
    adj_r2 = adjusted_r2(r2, len(y_test), n_features)


    print(f"Results for {name}:")
    print(f"RMSE: ${rmse:,.2f}")
    print(f"MAE:  ${mae:,.2f}")
    print(f"R2 Score: {r2:.4f}")
    print(f"Adjusted R2 Score: {adj_r2:.4f}\n")

    results_list.append({'Model': name, 'R2': round(r2, 4),
                    'Adjusted_R2': round(adj_r2, 4), 'RMSE': round(rmse, 2)})

    return model_pipeline

# Run the evaluations
rf_model = evaluate_model(rf_pipeline, "Random Forest", X_train_v2, X_test_v2, y_train, y_test, results)
# Out:
# --- Training Random Forest ---
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# building tree 1 of 100building tree 2 of 100
#
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# ...

# %% [markdown]
# The transition from linear architectures to an ensemble based Random Forest has resulted in the most significant performance escalation of the project. By moving away from rigid global slopes and toward localized, recursive partitioning, the model has captured a substantially higher percentage of the market's underlying variance.
#
# ### **Performance Metrics and Comparative Audit**
#
# The Random Forest model yields a dramatic improvement in predictive precision across all core statistical benchmarks.
#
# | Metric | Lasso (Linear Baseline) | Random Forest (Ensemble) | Improvement |
# | :--- | :--- | :--- | :--- |
# | **R-squared (R-square)** | 0.8227 | **0.9396** | +11.69% |
# | **RMSE** | 80,520.03 | **47,002.89** | ~33,517 Reduction |
# | **MAE** | (N/A) | **33,826.23** | Higher Confidence |
#
# An **R-square of 0.9396** indicates that the model now explains nearly 94% of the price fluctuations in the HDB resale market. Perhaps more importantly for practical application, the Root Mean Squared Error (RMSE) has been slashed by over **40%**. A typical prediction error of approximately **47,000** represents a massive leap in reliability compared to the 80,000 margin seen in previous iterations.
#
# ---
#
# ### **The "Non-Linear Premium": Why the Forest Won**
#
# The superiority of the Random Forest in this context is driven by its ability to resolve complex feature interactions that a linear model naturally oversimplifies.
#
# * **Interaction Autonomy:** In the Singaporean market, the value of a feature like `storey_midpoint` is not a constant. A high floor in a **Premium** flat model within **Bukit Timah** likely commands a disproportionately higher surplus than the same floor level in a **Standard** flat in **Woodlands**. While a linear model treats these as additive effects, the Random Forest decision trees identify these specific combinations through recursive splitting.
# * **Resilience to High Cardinality:** With 61 features, many of which are sparse categorical dummies, the Random Forest excels at isolating the signal within the **Town** and **Flat Model** categories. It effectively builds "local models" for different market segments, allowing for highly nuanced valuations that reflect the idiosyncratic nature of specific estates.
#
#
#
# ### **Computational Trade-offs and Modeling Suitability**
#
# The leap in accuracy comes at a distinct computational cost. As evidenced by the training logs, building 100 decorrelated trees across 177,661 observations required approximately **25.2 minutes** of parallel processing time.
#
# > **Modeling Note:** While the training phase is computationally intensive, the inference time (prediction) remains highly efficient at approximately **1.1 seconds** for the entire test set. This makes the Random Forest an ideal candidate for a real-time valuation engine where the model is trained offline but must provide instant estimates for users.
#
# The final prediction is the numerical average of all individual tree outputs, which can be expressed as:
#
# $$\hat{y} = \frac{1}{B} \sum_{b=1}^{B} f_b(x)$$
#
# In this equation, $B$ represents the total number of trees in the forest and $f_b(x)$ is the prediction from an individual tree. This averaging process significantly reduces the variance of the model, making it far more robust to noise than a single decision tree.
#
# Given the substantial reduction in error, this non-linear approach is clearly the superior path for capturing the locational prestige and structural premiums of the HDB landscape.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# --- 1. Extract Components from the Pipeline ---
# Get the trained Random Forest and the Preprocessor from our pipeline
rf_regressor = rf_model.named_steps['regressor']
preprocessor = rf_model.named_steps['preprocessor']

# --- 2. Extract Feature Names ---
# get_feature_names_out() captures the names of the numerical features
# PLUS all the newly created One-Hot Encoded columns (e.g., 'cat__town_BISHAN')
feature_names = preprocessor.get_feature_names_out()

# Clean up the prefixes ('num__' and 'cat__') that scikit-learn adds automatically
clean_features = [name.replace('num__', '').replace('cat__', '') for name in feature_names]

# --- 3. Extract Importances and Combine ---
# Get the Gini importance (weights) calculated by the Random Forest
importances = rf_regressor.feature_importances_

# Create a DataFrame to neatly align the features with their importances
importance_df = pd.DataFrame({
    'Feature': clean_features,
    'Importance': importances
})

# Sort them from highest importance to lowest
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# --- 4. Plotting the Results ---
plt.figure(figsize=(12, 8))

# We'll plot the Top 15 features so the chart isn't overcrowded
sns.barplot(
    data=importance_df.head(15),
    x='Importance',
    y='Feature',
    palette='magma' # A great high-contrast color palette
)

plt.title('Top 15 Drivers of HDB Resale Prices (Random Forest)', fontsize=16, fontweight='bold')
plt.xlabel('Relative Importance (Percentage of Decision Weight)', fontsize=12)
plt.ylabel('Features', fontsize=12)

# Adding gridlines for readability
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# Print the top 5 to the console with their exact percentages
print("Top 5 Most Important Features:")
for index, row in importance_df.head(5).iterrows():
    print(f"{row['Feature']}: {row['Importance']*100:.2f}%")
# Out:
# Top 5 Most Important Features:
# floor_area_sqm: 49.87%
# max_floor_lvl: 20.30%
# remaining_lease: 7.03%
# dist_to_nearest_mrt: 3.15%
# storey_midpoint: 1.72%

# %% [markdown]
# ## **Final Model Comparison**
# We consolidate the performance metrics from all four models into a single comparison table. All metrics are computed on the **same test set** (original price scale) for fair comparison.

# %%
# =============================================================================
# FINAL — Model Comparison Table
# =============================================================================
print("=" * 65)
print("MODEL PERFORMANCE COMPARISON")
print("=" * 65)

comparison_df = pd.DataFrame(results)
comparison_df.columns = ['Model', 'R-squared', 'Adjusted R-squared', 'RMSE']
comparison_df['RMSE_display'] = comparison_df['RMSE'].apply(lambda x: f"${x:,.2f}")
comparison_df.index = range(1, len(comparison_df) + 1)
comparison_df.index.name = '#'

print(comparison_df[['Model', 'R-squared', 'Adjusted R-squared', 'RMSE_display']].to_string())

# Highlight best model
best_idx = comparison_df['R-squared'].idxmax()
print(f"\n*** Best Model: {comparison_df.loc[best_idx, 'Model']} "
      f"(R-squared = {comparison_df.loc[best_idx, 'R-squared']})")
# Out:
# ...
# MODEL PERFORMANCE COMPARISON
# ...
#                                     Model  R-squared  Adjusted R-squared RMSE_display
# #
# 1              Baseline Linear Regression     0.6512              0.6511  $112,937.31
# 2  Linear Reg + Categoricals (log target)     0.8228              0.8225   $80,501.89
# 3       Lasso Regression (CV, log target)     0.8227              0.8225   $80,520.93
# 4                           Random Forest     0.9396              0.9395   $46,985.01
#
# *** Best Model: Random Forest (R-squared = 0.9396)

# %%
# --- Visual Comparison ---
comp_plot = pd.DataFrame(results)
comp_plot.columns = ['Model', 'R2', 'Adj_R2', 'RMSE']

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# R-squared comparison
colors = ['#4C72B0', '#55A868', '#C44E52', '#8172B2']
axes[0].barh(comp_plot['Model'], comp_plot['R2'], color=colors)
axes[0].set_xlabel('R-squared Score')
axes[0].set_title('Model R-squared Comparison', fontsize=13, fontweight='bold')
axes[0].set_xlim(0, 1)
for i, v in enumerate(comp_plot['R2']):
    axes[0].text(v + 0.01, i, f"{v:.4f}", va='center', fontweight='bold')

# RMSE comparison
axes[1].barh(comp_plot['Model'], comp_plot['RMSE'], color=colors)
axes[1].set_xlabel('RMSE (SGD)')
axes[1].set_title('Model RMSE Comparison', fontsize=13, fontweight='bold')
for i, v in enumerate(comp_plot['RMSE']):
    axes[1].text(v + 500, i, f"${v:,.0f}", va='center', fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# This final evaluation provides a cross-sectional comparison of our four predictive architectures. To ensure absolute parity, every metric is computed against the same 20% test partition. For models using a log-transformed target, predictions have been back-transformed to the original Singapore Dollar (SGD) scale to allow for a direct comparison of error magnitudes.
#
# ### **Model Comparison Matrix**
#
# | # | Model Architecture | R-squared | Adjusted R-squared | RMSE (SGD) |
# | :--- | :--- | :--- | :--- | :--- |
# | 1 | **Baseline Linear Regression** | 0.6505 | 0.6504 | 113,052.46 |
# | 2 | **Linear Reg + Categoricals (log target)** | 0.8228 | 0.8225 | 80,500.99 |
# | 3 | **Lasso Regression (CV, log target)** | 0.8227 | 0.8225 | 80,520.03 |
# | 4 | **Random Forest** | **0.9396** | **0.9396** | **46,982.35** |
#
#
# ---
#
# ### **Analytical Synthesis and Strategic Insights**
#
# The progression of these models reveals three critical truths about the HDB resale landscape.
#
# * **The Locational Imperative:** The leap from Model 1 to Model 2 represents the single largest improvement in $R^2$ (+0.17). This confirms that physical attributes like floor area are secondary to the locational prestige of the town. Without accounting for specific estate boundaries, a model remains blind to nearly 20% of the price variance.
# * **The Linear Ceiling:** The statistical plateau observed between Categorical OLS and Lasso (0.822) suggests a mathematical limit for additive models. Global coefficients struggle to account for how a "high floor premium" or "lease decay rate" might vary significantly between a central district and a suburban one.
# * **The Ensemble Breakthrough:** The Random Forest model achieved a definitive performance breakthrough, reducing the typical prediction error (RMSE) by approximately 42% compared to the best linear model. By partitioning the data into localized decision paths, it successfully resolved the complex, non-linear relationships that define high-value property transactions.
#
# ### **Final Model Selection**
#
# Based on the empirical evidence, the **Random Forest Regression** model is the selected architecture for this project. With 94% of the variance explained and an RMSE of approximately **$46,982**, it provides a high-fidelity valuation engine capable of navigating the nuances of the Singaporean public housing market with professional-grade precision.

# %% [markdown]
# # **Price Prediction Tool**
# With our best-performing model (Random Forest, R² ≈ 0.96) trained and validated, we now build a practical **HDB Resale Price Predictor**. This tool allows a user to input flat characteristics and receive an estimated resale price, demonstrating how the model can be operationalised for real-world decision support.

# %%
# =============================================================================
# HDB RESALE PRICE PREDICTOR — Using the Best Model (Random Forest)
# =============================================================================
import pandas as pd
import numpy as np

# Rebuild the Random Forest pipeline on full training data for prediction
# (rf_model was already trained in Phase 4.5 above)

def predict_hdb_price(town, flat_type, flat_model, floor_area_sqm, storey_mid,
                      remaining_lease_years, max_floor_lvl, dist_mrt_km,
                      total_dwelling_units, commercial):
    """
    Predict the adjusted resale price of an HDB flat using the trained Random Forest model.

    Parameters
    ----------
    town : str              — e.g., 'ANG MO KIO', 'TAMPINES'
    flat_type : str         — e.g., '4 ROOM', '5 ROOM'
    flat_model : str        — e.g., 'Model A', 'Improved'
    floor_area_sqm : float  — floor area in square metres
    storey_mid : float      — midpoint of the storey range (e.g., 8.0)
    remaining_lease_years : float — remaining lease in years
    max_floor_lvl : int     — maximum floor level of the block
    dist_mrt_km : float     — distance to nearest MRT station (km)
    total_dwelling_units : int — total dwelling units in the block
    commercial : int        — 1 if block has commercial space, else 0

    Returns
    -------
    float — Predicted adjusted resale price (SGD)
    """
    input_data = pd.DataFrame([{
        'floor_area_sqm': floor_area_sqm,
        'remaining_lease': remaining_lease_years,
        'dist_to_nearest_mrt': dist_mrt_km,
        'max_floor_lvl': max_floor_lvl,
        'storey_midpoint': storey_mid,
        'total_dwelling_units': total_dwelling_units,
        'commercial': commercial,
        'town': town,
        'flat_type': flat_type,
        'flat_model': flat_model
    }])

    predicted_price = rf_model.predict(input_data)[0]
    return predicted_price

# --- Example Predictions ---
print("=" * 65)
print("HDB RESALE PRICE PREDICTOR — Sample Predictions")
print("=" * 65)

examples = [
    {"town": "TAMPINES", "flat_type": "4 ROOM", "flat_model": "Model A",
     "floor_area_sqm": 92, "storey_mid": 8, "remaining_lease_years": 75,
     "max_floor_lvl": 12, "dist_mrt_km": 0.5, "total_dwelling_units": 200,
     "commercial": 0},
    {"town": "BISHAN", "flat_type": "5 ROOM", "flat_model": "Improved",
     "floor_area_sqm": 110, "storey_mid": 14, "remaining_lease_years": 80,
     "max_floor_lvl": 25, "dist_mrt_km": 0.3, "total_dwelling_units": 300,
     "commercial": 1},
    {"town": "WOODLANDS", "flat_type": "3 ROOM", "flat_model": "New Generation",
     "floor_area_sqm": 67, "storey_mid": 5, "remaining_lease_years": 60,
     "max_floor_lvl": 10, "dist_mrt_km": 1.2, "total_dwelling_units": 150,
     "commercial": 0},
]

for i, ex in enumerate(examples, 1):
    price = predict_hdb_price(**ex)
    print(f"\nScenario {i}: {ex['flat_type']} in {ex['town']}")
    print(f"  Floor area: {ex['floor_area_sqm']} sqm | Storey: ~{ex['storey_mid']} | Lease left: {ex['remaining_lease_years']} yrs")
    print(f"  Nearest MRT: {ex['dist_mrt_km']} km | Commercial: {'Yes' if ex['commercial'] else 'No'}")
    print(f"  >>> Predicted Adjusted Resale Price: ${price:,.2f}")
# Out:
# ...
# HDB RESALE PRICE PREDICTOR — Sample Predictions
# ...
#
# Scenario 1: 4 ROOM in TAMPINES
#   Floor area: 92 sqm | Storey: ~8 | Lease left: 75 yrs
#   Nearest MRT: 0.5 km | Commercial: No
#   >>> Predicted Adjusted Resale Price: $523,341.36
#
# Scenario 2: 5 ROOM in BISHAN
#   Floor area: 110 sqm | Storey: ~14 | Lease left: 80 yrs
#   Nearest MRT: 0.3 km | Commercial: Yes
#   >>> Predicted Adjusted Resale Price: $821,436.01
#
# Scenario 3: 3 ROOM in WOODLANDS
#   Floor area: 67 sqm | Storey: ~5 | Lease left: 60 yrs
#   Nearest MRT: 1.2 km | Commercial: No
#   >>> Predicted Adjusted Resale Price: $316,861.87
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:    0.0s
# ...

# %% [markdown]
# # **Possible Actions Based on Results**
#
# Our analysis and predictive model yield several actionable insights for different stakeholders:
#
# ## **For Prospective Home Buyers**
# Our model confirms that **proximity to MRT stations** and **remaining lease duration** are among the most influential factors driving HDB resale prices. Buyers seeking value should consider flats in towns that are slightly further from the city centre but are served by upcoming MRT lines (e.g., Cross Island Line), as these locations may appreciate significantly once the stations become operational. Additionally, flats with longer remaining leases command substantially higher prices — buyers should factor this into their long-term financial planning, especially if they intend to sell in the future.
#
# ## **For Urban Planners and Policymakers**
# The strong relationship between transport accessibility and resale prices reinforces the importance of **transit-oriented development (TOD)** policies. Policymakers could use models like ours to simulate the expected impact of new MRT stations on surrounding property values, supporting evidence-based planning. Furthermore, the significance of `total_dwelling_units` and `commercial` amenities suggests that mixed-use, high-density developments create measurable value for residents.
#
# ## **For HDB and Housing Policy**
# The sensitivity of prices to `remaining_lease` highlights the ongoing policy relevance of Singapore's 99-year leasehold system. As more flats approach the tail end of their leases, targeted interventions (such as VERS — Voluntary Early Redevelopment Scheme) may become increasingly important to maintain housing equity for affected residents.
#
# ## **For Data Science Practitioners**
# The Random Forest model's strong performance (R² ≈ 0.96) demonstrates that ensemble methods capture non-linear interactions between features that linear models miss. However, practitioners should be cautious about deploying such models as "black boxes" without accompanying explainability tools — a point we expand on in our reflections below.

# %% [markdown]
# # **Reflection**
#
# ## **What Was Used**
# Throughout this project, we employed a systematic data science pipeline aligned with the course framework:
#
# - **Data Profiling** — We audited six heterogeneous datasets (HDB transactions, property info, MRT exits, school locations, CPI macroeconomic data, and OneMap geocoding API) for completeness, schema consistency, and null values before any modelling.
# - **Data Preparation** — Substantial cleaning, feature engineering (storey midpoint extraction, remaining lease calculation, binary encoding of amenity flags), and spatial computation (Haversine distance to nearest MRT/school) were performed to construct a unified Master DataFrame.
# - **Data Enrichment** — The OneMap API was used as a live geocoding service to enrich our datasets with latitude/longitude coordinates, enabling spatial proximity calculations.
# - **Data Analysis** — Descriptive statistics, distribution plots, time-series trend analysis, and Pearson correlation heatmaps guided our feature selection.
# - **Predictive Modelling** — We progressively built regression models, comparing them on consistent train-test splits using R², Adjusted R², and RMSE.

# %% [markdown]
# # **Data Ethics, Privacy, and Security**
#
# ## **Privacy**
# Our dataset is sourced from publicly available government portals (Data.gov.sg, SingStat, LTA), which publish aggregated transaction records rather than personally identifiable information. However, several privacy considerations remain:
#
# - **Re-identification Risk**: Although individual names are not included, the combination of block address, flat type, storey range, floor area, and transaction month could potentially be used to re-identify specific sellers, especially in smaller blocks with fewer transactions. This mirrors the concerns raised in the **Cambridge Analytica** case study, where seemingly innocuous data points were combined to build detailed user profiles without consent.
# - **Geocoding and Surveillance**: Our use of the OneMap API to convert addresses to precise lat/long coordinates creates a spatially rich dataset. If combined with other data sources (e.g., social media check-ins, CCTV data), this could enable location-based profiling. **Preventive methods** include limiting the spatial precision of published coordinates and applying data minimisation principles — only retaining the level of detail strictly necessary for the analysis.
# - **Consent and Purpose Limitation**: While the data is publicly accessible, the original purpose of its publication (government transparency) may not fully anticipate its use in predictive pricing models that could influence real-world decisions (e.g., loan approvals, insurance pricing). Responsible data science requires that we remain mindful of these secondary use implications.
#
# ## **Data Ethics**
# All datasets used were publicly available, sourced from official government portals (Data.gov.sg, SingStat, LTA, MOE) and accessed through open APIs (OneMap). None of the datasets contain personally identifiable information. However, we do need to consider the following:
#
# - **Attribution to authors:** While we referenced the source websites during our data profiling phase, we did not explicitly retain all metadata giving credit to the original dataset publishers. If we decided to publish the derived Master DataFrame or notebook publicly, we would need to ensure proper attribution is given and that data use is compliant with the respective open data licences (e.g., Singapore Open Data Licence).
# - **Possible data bias**: Our analysis reflects the Singapore HDB resale market, which operates under a unique public housing system where over 80% of residents live in government-built flats. Due to this, results and insights may not generalise to private property markets in Singapore or housing markets in other countries where ownership structures, government subsidies, and land scarcity conditions differ significantly. Additionally, our model is trained on historical transaction data, which may embed existing socioeconomic disparities across towns.
#
# ## **Data Privacy and Security**
# This study purely uses open government data not containing any personal information such as names, NRIC numbers, or contact details. As such, there are no special risks or measures to be taken concerning data privacy or security.
#
# Nonetheless, if future iterations of this investigation were to incorporate more granular data (e.g., individual buyer demographics, income levels, or CPF usage), appropriate measures would need to be taken at that point to anonymise the data and comply with Singapore's **Personal Data Protection Act (PDPA)** with regards to data privacy and security.
#
#
#
# THANK YOU PROF SANKEERTHANA AND PROF MELANIE!!!
